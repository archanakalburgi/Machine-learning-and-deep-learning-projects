# %% [markdown]
# ## Homework 2: Deep Learning Foundation

# %% [markdown]
# ### Obbjectives:
# - Create sequential models
# - Practice training deep learning models with PyTorch
# - Learn how to use different techniques to fight with underfitting and overfitting
#     - Model architecture: shallow vs. deep
#     - Regularizers
#
# Note, check `Lab 2: Overfitting_Underfitting` before you start working on this assignment. The lab should give you a good starting point.

# %% [markdown]
# ### Description:  Classifying newswires: a multi-class classification

# %% [markdown]
# - In this assignment, we will build a network to classify Reuters newswires into 46 different mutually-exclusive topics.
# - Since we have many classes and each data point should be classified into only one category, the problem is specifically an instance of <b>"single-label, multi-class classification"</b>.

# %% [markdown]
# ### The Reuters dataset
#
# - _Reuters dataset_, is a set of short newswires and their topics, published by Reuters in 1986.
# - There are 46 different topics some topics are more represented than others, but each topic has at least 10 examples in the training set.
# - The dataset can be loaded using the following script. Specifically, it retrieves 8,982 training examples and 2,246 test examples. The argument `num_words=10000` restricts the data to the 10,000 most frequently occurring words found in the data.
#
# Note, here we only use Keras to download the dataset. Your deep learning model should be done by PyTorch.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import tensorflow.keras
from tensorflow.keras.datasets import reuters
import pandas as pd

from torchinfo import summary

import matplotlib.pyplot as plt

# add your import statement

# %%
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# show the sizes training/testing samples 
len(train_data)
len(test_data)
# Out:
# 8982
# 2246

# %% [markdown]
# Each example is a list of integers, each corresponds to one word (word indices).  The following shows one example. Also, you can decode it back to words, in case you are curious:

# %%
# show an example from the training dataset
print(train_data[10])

# retrieve the mapping from words to indices
word_index = reuters.get_word_index()

# reverse mapping
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# Note that our indices were offset by 3
# because 0, 1 and 2 are reserved indices for "padding", "start of sequence", and "unknown".
decoded_newswire = ' '.join([reverse_word_index[i - 3] for i in train_data[0] if (i-3) in reverse_word_index])

decoded_newswire
# Out:
# [1, 245, 273, 207, 156, 53, 74, 160, 26, 14, 46, 296, 26, 39, 74, 2979, 3554, 14, 46, 4689, 4329, 86, 61, 3499, 4795, 14, 61, 451, 4329, 17, 12]
# 'said as a result of its december acquisition of space co it expects earnings per share in 1987 of 1 15 to 1 30 dlrs per share up from 70 cts in 1986 the company said pretax net should rise to nine to 10 mln dlrs from six mln dlrs in 1986 and rental operation revenues to 19 to 22 mln dlrs from 12 5 mln dlrs it said cash flow per share this year should be 2 50 to three dlrs reuter 3'

# %% [markdown]
# The label associated with an example is an integer between 0 and 45: a topic index. In total, there are `46` topics.
#
#
# The code below shows the label for one sample and also the distribution of labels. This dataset is very imbalanced. Some labels only have a few training samples.

# %%
train_labels[10]

# distribution of labels

pd.Series(train_labels).value_counts().sort_values(ascending = False)
# Out:
# 3
# 3     3159
# 4     1949
# 19     549
# 16     444
# 1      432
# 11     390
# 20     269
# 13     172
# 8      139
# 10     124
# 9      101
# 21     100
# 25      92
# 2       74
# 18      66
# 24      62
# 0       55
# 34      50
# 12      49
# 36      49
# 6       48
# 28      48
# 30      45
# 23      41
# 31      39
# 17      39
# 40      36
# 32      32
# 41      30
# 14      26
# 39      24
# 26      24
# 43      21
# 15      20
# 38      19
# 37      19
# 29      19
# 45      18
# 5       17
# 7       16
# 27      15
# 22      15
# 42      13
# 44      12
# 33      11
# 35      10
# dtype: int64

# %% [markdown]
# ### Prepare data
# First, we'll follow the "bad-of-words" approach to generating sample representations. You can vectorize the data with the following code. Specifically,
# - The training/test datasets is represented as a matrix
# - Each sample is treated as a row, and each word is a column.
# - If a word (say $j$) appears in a sample (say $i$), 1 is recorded in the cell ($i, j$), and 0 otherwise.

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# Get Y ready
y_train = np.array(train_labels)
y_test = np.array(test_labels)

x_train.shape
x_test.shape

y_train.shape
y_test.shape
# Out:
# (8982, 10000)
# (2246, 10000)
# (8982,)
# (2246,)

# %% [markdown]
# ### Q1: Create seqential models in different architectures
#
#
# - Create three different sequential models as defined below. Use `ReLu` activation function for all hidden layers.
#     - Model A: This model only has one hidden layer with 128 units.
#     - Model B: Similar to A, but this model adds a 2nd hidden layer with 64 units.
#     - Model C: This model is similar to Model B except that the 2nd hidden layer has 16 units.
#
#
# - Define a function `fit_model(model, train_dataset, test_dataset, *other parameters if appropriate* )`, and use this function to train each model. You'll need to tune hyperparameters. To help you get started, suggested values for some parameters are provided:
#     - optimizer: RMSProp optimizer or Adam
#     - loss: `pick a right loss function` from this list: https://pytorch.org/docs/stable/nn.html#loss-functions
#     - batch_size: 256
#     - epoch: 30
#     - learning rate: 0.0002
#
#
# - After each training epoch, calculate the loss and accuracy of each model on the test dataset (i.e. `x_test, y_test`)
#
#
# - Return training history. Plot test loss and accuracy vs. epoches from the training histories of these three models
#     - Reference plots are provided for your reference. You may generate different plots.
#     - In general, the best test accuracy of this problem should not be lower than `75%`.
#
#
# - Write your analysis (as markdowns) on the following:
#    - For each model, from which epoch, overfitting started happening?
#    - Which model in general performs better than the others in terms of test loss or test accuracy?
#    - Please explain why this model outperforms the others

# %%
# fix random number

random_seed = 124
seed(random_seed)

torch.manual_seed(random_seed)
torch.backends.cudnn.deterministic = True

# %%
# Create dataset class

class news_dataset(Dataset):
    
    # add your code

# %%
# Define your models: A, B, C

class linear_model(nn.Module):
    
    
    def __init__(self):  # add more parameters if needed
        
       # add your code
    
    def forward(self, x):
        
        output = x
        
        # add your code
        
        return output

# %%
# Define a train function


def train_model(model, train_dataset, test_dataset, device, epochs=50):  # add more parameters if needed
    
    train_history = None
    
    # add your code
  
    return train_history

# %%
# Train Model A

# dataset
train_dataset = news_dataset(x_train, y_train)
test_dataset = news_dataset(x_test, y_test)

# load model
modela = linear_model()
summary(modela, (24, 10000))
hista = train_model(modela, train_dataset, test_dataset, device, epochs=50)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             --                        --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [24, 128]                 1,280,128
# │    └─Linear: 2-2                       [24, 46]                  5,934
# ==========================================================================================
# Total params: 1,286,062
# Trainable params: 1,286,062
# Non-trainable params: 0
# Total mult-adds (M): 30.87
# ==========================================================================================
# Input size (MB): 0.96
# Forward/backward pass size (MB): 0.03
# Params size (MB): 5.14
# Estimated Total Size (MB): 6.14
# ==========================================================================================
# Training Start
# Epoch:1 / 50, train loss:2.50447 train_acc:0.56847, valid loss:1.90883 valid acc:0.62153
# Epoch:2 / 50, train loss:1.61858 train_acc:0.67263, valid loss:1.55625 valid acc:0.66840
# Epoch:3 / 50, train loss:1.31206 train_acc:0.71756, valid loss:1.38099 valid acc:0.68403
# Epoch:4 / 50, train loss:1.12910 train_acc:0.74479, valid loss:1.27654 valid acc:0.70399
# Epoch:5 / 50, train loss:1.02316 train_acc:0.77094, valid loss:1.19875 valid acc:0.71658
# Epoch:6 / 50, train loss:0.93204 train_acc:0.79080, valid loss:1.14146 valid acc:0.73220
# Epoch:7 / 50, train loss:0.86066 train_acc:0.80534, valid loss:1.10096 valid acc:0.74132
# Epoch:8 / 50, train loss:0.77987 train_acc:0.82129, valid loss:1.06166 valid acc:0.75434
# Epoch:9 / 50, train loss:0.72607 train_acc:0.83333, valid loss:1.02984 valid acc:0.75868
# Epoch:10 / 50, train loss:0.66612 train_acc:0.84288, valid loss:0.99503 valid acc:0.76302
# Epoch:11 / 50, train loss:0.62366 train_acc:0.85438, valid loss:0.97368 valid acc:0.76345
# Epoch:12 / 50, train loss:0.57312 train_acc:0.86350, valid loss:0.94754 valid acc:0.77083
# Epoch:13 / 50, train loss:0.53856 train_acc:0.87109, valid loss:0.92383 valid acc:0.77127
# Epoch:14 / 50, train loss:0.49469 train_acc:0.87652, valid loss:0.91053 valid acc:0.77387
# Epoch:15 / 50, train loss:0.46671 train_acc:0.88270, valid loss:0.89716 valid acc:0.77648
# Epoch:16 / 50, train loss:0.42465 train_acc:0.89030, valid loss:0.88284 valid acc:0.77908
# Epoch:17 / 50, train loss:0.39827 train_acc:0.89475, valid loss:0.87082 valid acc:0.77691
# Epoch:18 / 50, train loss:0.37079 train_acc:0.90050, valid loss:0.86607 valid acc:0.77908
# Epoch:19 / 50, train loss:0.34511 train_acc:0.90408, valid loss:0.85754 valid acc:0.78038
# Epoch:20 / 50, train loss:0.32187 train_acc:0.90690, valid loss:0.84943 valid acc:0.78385
# Epoch:21 / 50, train loss:0.29943 train_acc:0.91102, valid loss:0.84722 valid acc:0.78212
# Epoch:22 / 50, train loss:0.28523 train_acc:0.91395, valid loss:0.85091 valid acc:0.78038
# Epoch:23 / 50, train loss:0.26201 train_acc:0.91612, valid loss:0.84535 valid acc:0.78472
# Epoch:24 / 50, train loss:0.24905 train_acc:0.91905, valid loss:0.84302 valid acc:0.78255
# Epoch:25 / 50, train loss:0.23274 train_acc:0.92025, valid loss:0.83664 valid acc:0.78559
# Epoch:26 / 50, train loss:0.21859 train_acc:0.92253, valid loss:0.84076 valid acc:0.78299
# Epoch:27 / 50, train loss:0.20516 train_acc:0.92405, valid loss:0.84745 valid acc:0.78299
# Epoch:28 / 50, train loss:0.19791 train_acc:0.92459, valid loss:0.84770 valid acc:0.78385
# Epoch:29 / 50, train loss:0.18514 train_acc:0.92676, valid loss:0.85980 valid acc:0.78689
# Epoch:30 / 50, train loss:0.17970 train_acc:0.92763, valid loss:0.85973 valid acc:0.78602
# Epoch:31 / 50, train loss:0.16964 train_acc:0.92860, valid loss:0.85749 valid acc:0.78385
# Epoch:32 / 50, train loss:0.16354 train_acc:0.92752, valid loss:0.86717 valid acc:0.78819
# Epoch:33 / 50, train loss:0.15474 train_acc:0.93045, valid loss:0.86459 valid acc:0.78776
# Epoch:34 / 50, train loss:0.15339 train_acc:0.93066, valid loss:0.88538 valid acc:0.78168
# Epoch:35 / 50, train loss:0.14447 train_acc:0.93110, valid loss:0.87874 valid acc:0.78385
# Epoch:36 / 50, train loss:0.14176 train_acc:0.93077, valid loss:0.89453 valid acc:0.78342
# Epoch:37 / 50, train loss:0.12999 train_acc:0.93186, valid loss:0.89460 valid acc:0.78689
# Epoch:38 / 50, train loss:0.12759 train_acc:0.93218, valid loss:0.89887 valid acc:0.78733
# Epoch:39 / 50, train loss:0.12702 train_acc:0.93164, valid loss:0.91746 valid acc:0.78255
# Epoch:40 / 50, train loss:0.11818 train_acc:0.93153, valid loss:0.90988 valid acc:0.78776
# Epoch:41 / 50, train loss:0.11923 train_acc:0.93153, valid loss:0.92056 valid acc:0.78689
# Epoch:42 / 50, train loss:0.11172 train_acc:0.93229, valid loss:0.92327 valid acc:0.78559
# Epoch:43 / 50, train loss:0.10989 train_acc:0.93283, valid loss:0.92999 valid acc:0.78602
# Epoch:44 / 50, train loss:0.11056 train_acc:0.93262, valid loss:0.93579 valid acc:0.78255
# Epoch:45 / 50, train loss:0.10511 train_acc:0.93305, valid loss:0.95253 valid acc:0.78602
# Epoch:46 / 50, train loss:0.10246 train_acc:0.93262, valid loss:0.95582 valid acc:0.78646
# Epoch:47 / 50, train loss:0.10017 train_acc:0.93370, valid loss:0.95826 valid acc:0.78689
# Epoch:48 / 50, train loss:0.09990 train_acc:0.93251, valid loss:0.96105 valid acc:0.78472
# Epoch:49 / 50, train loss:0.09599 train_acc:0.93381, valid loss:0.97540 valid acc:0.78255
# Epoch:50 / 50, train loss:0.09391 train_acc:0.93175, valid loss:0.98037 valid acc:0.78472

# %%
# Train Model B

# dataset
train_dataset = news_dataset(x_train, y_train)
test_dataset = news_dataset(x_test, y_test)

modelb = linear_model()
summary(modelb, (24, 10000))
histb = train_model(modelb, train_dataset, test_dataset, device, epochs = 50)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             --                        --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [24, 128]                 1,280,128
# │    └─Linear: 2-2                       [24, 64]                  8,256
# │    └─Linear: 2-3                       [24, 46]                  2,990
# ==========================================================================================
# Total params: 1,291,374
# Trainable params: 1,291,374
# Non-trainable params: 0
# Total mult-adds (M): 30.99
# ==========================================================================================
# Input size (MB): 0.96
# Forward/backward pass size (MB): 0.05
# Params size (MB): 5.17
# Estimated Total Size (MB): 6.17
# ==========================================================================================
# Training Start
# Epoch:1 / 50, train loss:2.66254 train_acc:0.50304, valid loss:1.92919 valid acc:0.58681
# Epoch:2 / 50, train loss:1.63426 train_acc:0.64399, valid loss:1.57192 valid acc:0.64540
# Epoch:3 / 50, train loss:1.36719 train_acc:0.68837, valid loss:1.42369 valid acc:0.66710
# Epoch:4 / 50, train loss:1.21565 train_acc:0.71365, valid loss:1.33877 valid acc:0.68403
# Epoch:5 / 50, train loss:1.11870 train_acc:0.73318, valid loss:1.28153 valid acc:0.69097
# Epoch:6 / 50, train loss:1.01302 train_acc:0.75163, valid loss:1.23188 valid acc:0.69878
# Epoch:7 / 50, train loss:0.96438 train_acc:0.76823, valid loss:1.19370 valid acc:0.72135
# Epoch:8 / 50, train loss:0.87985 train_acc:0.78668, valid loss:1.15158 valid acc:0.72569
# Epoch:9 / 50, train loss:0.81390 train_acc:0.80132, valid loss:1.12761 valid acc:0.73047
# Epoch:10 / 50, train loss:0.75328 train_acc:0.81380, valid loss:1.09677 valid acc:0.73220
# Epoch:11 / 50, train loss:0.70880 train_acc:0.82281, valid loss:1.06107 valid acc:0.74392
# Epoch:12 / 50, train loss:0.66083 train_acc:0.83214, valid loss:1.05113 valid acc:0.74826
# Epoch:13 / 50, train loss:0.62189 train_acc:0.84288, valid loss:1.03933 valid acc:0.74913
# Epoch:14 / 50, train loss:0.56425 train_acc:0.85102, valid loss:1.01948 valid acc:0.75304
# Epoch:15 / 50, train loss:0.53511 train_acc:0.86122, valid loss:0.99987 valid acc:0.75217
# Epoch:16 / 50, train loss:0.48424 train_acc:0.86871, valid loss:0.99651 valid acc:0.75174
# Epoch:17 / 50, train loss:0.45009 train_acc:0.87826, valid loss:0.98716 valid acc:0.75868
# Epoch:18 / 50, train loss:0.41841 train_acc:0.88563, valid loss:0.98135 valid acc:0.75868
# Epoch:19 / 50, train loss:0.40108 train_acc:0.89138, valid loss:1.00168 valid acc:0.75651
# Epoch:20 / 50, train loss:0.37047 train_acc:0.89692, valid loss:0.98912 valid acc:0.76823
# Epoch:21 / 50, train loss:0.33985 train_acc:0.90158, valid loss:0.97233 valid acc:0.76866
# Epoch:22 / 50, train loss:0.32087 train_acc:0.90451, valid loss:0.98245 valid acc:0.76823
# Epoch:23 / 50, train loss:0.29808 train_acc:0.90766, valid loss:0.98680 valid acc:0.77127
# Epoch:24 / 50, train loss:0.27481 train_acc:0.91319, valid loss:0.98186 valid acc:0.77040
# Epoch:25 / 50, train loss:0.26233 train_acc:0.91439, valid loss:0.99754 valid acc:0.77431
# Epoch:26 / 50, train loss:0.25210 train_acc:0.91786, valid loss:1.02011 valid acc:0.77127
# Epoch:27 / 50, train loss:0.23323 train_acc:0.91992, valid loss:1.00905 valid acc:0.77517
# Epoch:28 / 50, train loss:0.22307 train_acc:0.92068, valid loss:1.01479 valid acc:0.77561
# Epoch:29 / 50, train loss:0.20748 train_acc:0.92296, valid loss:1.01670 valid acc:0.77300
# Epoch:30 / 50, train loss:0.19948 train_acc:0.92361, valid loss:1.01728 valid acc:0.77387
# Epoch:31 / 50, train loss:0.18970 train_acc:0.92394, valid loss:1.01939 valid acc:0.77648
# Epoch:32 / 50, train loss:0.17470 train_acc:0.92491, valid loss:1.03199 valid acc:0.77604
# Epoch:33 / 50, train loss:0.17069 train_acc:0.92502, valid loss:1.04889 valid acc:0.77648
# Epoch:34 / 50, train loss:0.16243 train_acc:0.92784, valid loss:1.03955 valid acc:0.77778
# Epoch:35 / 50, train loss:0.15453 train_acc:0.92871, valid loss:1.05836 valid acc:0.77604
# Epoch:36 / 50, train loss:0.14909 train_acc:0.92817, valid loss:1.08251 valid acc:0.76953
# Epoch:37 / 50, train loss:0.14557 train_acc:0.92860, valid loss:1.10790 valid acc:0.76823
# Epoch:38 / 50, train loss:0.14131 train_acc:0.93099, valid loss:1.09851 valid acc:0.77908
# Epoch:39 / 50, train loss:0.13843 train_acc:0.93045, valid loss:1.08429 valid acc:0.77734
# Epoch:40 / 50, train loss:0.13046 train_acc:0.92925, valid loss:1.14886 valid acc:0.76910
# Epoch:41 / 50, train loss:0.12618 train_acc:0.93056, valid loss:1.10319 valid acc:0.77691
# Epoch:42 / 50, train loss:0.12066 train_acc:0.93099, valid loss:1.13950 valid acc:0.77257
# Epoch:43 / 50, train loss:0.11887 train_acc:0.93327, valid loss:1.14255 valid acc:0.77083
# Epoch:44 / 50, train loss:0.11386 train_acc:0.93240, valid loss:1.12641 valid acc:0.77561
# Epoch:45 / 50, train loss:0.11099 train_acc:0.93175, valid loss:1.13430 valid acc:0.77387
# Epoch:46 / 50, train loss:0.10946 train_acc:0.93283, valid loss:1.16493 valid acc:0.77387
# Epoch:47 / 50, train loss:0.10700 train_acc:0.93186, valid loss:1.15894 valid acc:0.77214
# Epoch:48 / 50, train loss:0.10803 train_acc:0.93142, valid loss:1.20040 valid acc:0.76823
# Epoch:49 / 50, train loss:0.10567 train_acc:0.93186, valid loss:1.20748 valid acc:0.76519
# Epoch:50 / 50, train loss:0.10229 train_acc:0.93392, valid loss:1.19765 valid acc:0.76997

# %%
# Train Model C

# dataset
train_dataset = news_dataset(x_train, y_train)
test_dataset = news_dataset(x_test, y_test)

modelc = linear_model()
summary(modelc, (24, 10000))
histc = train_model(modelc, train_dataset, test_dataset, device, epochs = 50)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# linear_model                             --                        --
# ├─ModuleList: 1-1                        --                        --
# │    └─Linear: 2-1                       [24, 128]                 1,280,128
# │    └─Linear: 2-2                       [24, 16]                  2,064
# │    └─Linear: 2-3                       [24, 46]                  782
# ==========================================================================================
# Total params: 1,282,974
# Trainable params: 1,282,974
# Non-trainable params: 0
# Total mult-adds (M): 30.79
# ==========================================================================================
# Input size (MB): 0.96
# Forward/backward pass size (MB): 0.04
# Params size (MB): 5.13
# Estimated Total Size (MB): 6.13
# ==========================================================================================
# Training Start
# Epoch:1 / 50, train loss:3.06434 train_acc:0.43414, valid loss:2.40988 valid acc:0.54427
# Epoch:2 / 50, train loss:2.02661 train_acc:0.58876, valid loss:1.86694 valid acc:0.60026
# Epoch:3 / 50, train loss:1.65761 train_acc:0.63194, valid loss:1.66889 valid acc:0.61936
# Epoch:4 / 50, train loss:1.46962 train_acc:0.65820, valid loss:1.54148 valid acc:0.65148
# Epoch:5 / 50, train loss:1.34223 train_acc:0.67980, valid loss:1.46147 valid acc:0.65451
# Epoch:6 / 50, train loss:1.23084 train_acc:0.69141, valid loss:1.40033 valid acc:0.66059
# Epoch:7 / 50, train loss:1.17953 train_acc:0.70530, valid loss:1.36265 valid acc:0.66667
# Epoch:8 / 50, train loss:1.11866 train_acc:0.71929, valid loss:1.31193 valid acc:0.67535
# Epoch:9 / 50, train loss:1.03261 train_acc:0.73492, valid loss:1.28030 valid acc:0.68490
# Epoch:10 / 50, train loss:0.98506 train_acc:0.74978, valid loss:1.25824 valid acc:0.68750
# Epoch:11 / 50, train loss:0.93409 train_acc:0.76074, valid loss:1.22729 valid acc:0.70052
# Epoch:12 / 50, train loss:0.89114 train_acc:0.77224, valid loss:1.20199 valid acc:0.70530
# Epoch:13 / 50, train loss:0.84180 train_acc:0.78548, valid loss:1.17886 valid acc:0.70833
# Epoch:14 / 50, train loss:0.80765 train_acc:0.79503, valid loss:1.15846 valid acc:0.71484
# Epoch:15 / 50, train loss:0.76024 train_acc:0.80425, valid loss:1.14202 valid acc:0.71962
# Epoch:16 / 50, train loss:0.72967 train_acc:0.81402, valid loss:1.14166 valid acc:0.71745
# Epoch:17 / 50, train loss:0.69018 train_acc:0.82270, valid loss:1.11341 valid acc:0.72830
# Epoch:18 / 50, train loss:0.65164 train_acc:0.83084, valid loss:1.11286 valid acc:0.72873
# Epoch:19 / 50, train loss:0.62286 train_acc:0.83865, valid loss:1.09296 valid acc:0.73698
# Epoch:20 / 50, train loss:0.58330 train_acc:0.84581, valid loss:1.09146 valid acc:0.73264
# Epoch:21 / 50, train loss:0.56073 train_acc:0.85004, valid loss:1.07544 valid acc:0.74089
# Epoch:22 / 50, train loss:0.53307 train_acc:0.85764, valid loss:1.07031 valid acc:0.74262
# Epoch:23 / 50, train loss:0.50507 train_acc:0.86317, valid loss:1.06889 valid acc:0.74002
# Epoch:24 / 50, train loss:0.47818 train_acc:0.86643, valid loss:1.05914 valid acc:0.74132
# Epoch:25 / 50, train loss:0.45799 train_acc:0.87196, valid loss:1.06140 valid acc:0.74349
# Epoch:26 / 50, train loss:0.42068 train_acc:0.87674, valid loss:1.06307 valid acc:0.74219
# Epoch:27 / 50, train loss:0.40086 train_acc:0.87999, valid loss:1.06435 valid acc:0.74392
# Epoch:28 / 50, train loss:0.39106 train_acc:0.88368, valid loss:1.05860 valid acc:0.74653
# Epoch:29 / 50, train loss:0.37180 train_acc:0.88889, valid loss:1.05870 valid acc:0.75000
# Epoch:30 / 50, train loss:0.35567 train_acc:0.89366, valid loss:1.07811 valid acc:0.74826
# Epoch:31 / 50, train loss:0.32823 train_acc:0.89779, valid loss:1.06088 valid acc:0.75217
# Epoch:32 / 50, train loss:0.31736 train_acc:0.90093, valid loss:1.07593 valid acc:0.75260
# Epoch:33 / 50, train loss:0.29599 train_acc:0.90299, valid loss:1.08624 valid acc:0.75000
# Epoch:34 / 50, train loss:0.28069 train_acc:0.90625, valid loss:1.07556 valid acc:0.75347
# Epoch:35 / 50, train loss:0.27502 train_acc:0.91102, valid loss:1.07563 valid acc:0.75608
# Epoch:36 / 50, train loss:0.25984 train_acc:0.91243, valid loss:1.10123 valid acc:0.75391
# Epoch:37 / 50, train loss:0.25251 train_acc:0.91417, valid loss:1.09480 valid acc:0.75564
# Epoch:38 / 50, train loss:0.23362 train_acc:0.91645, valid loss:1.09975 valid acc:0.75564
# Epoch:39 / 50, train loss:0.22906 train_acc:0.91829, valid loss:1.12527 valid acc:0.75260
# Epoch:40 / 50, train loss:0.21788 train_acc:0.91981, valid loss:1.11197 valid acc:0.75434
# Epoch:41 / 50, train loss:0.20697 train_acc:0.92057, valid loss:1.12507 valid acc:0.75521
# Epoch:42 / 50, train loss:0.20154 train_acc:0.92426, valid loss:1.13235 valid acc:0.75564
# Epoch:43 / 50, train loss:0.20160 train_acc:0.92437, valid loss:1.12904 valid acc:0.75825
# Epoch:44 / 50, train loss:0.18178 train_acc:0.92600, valid loss:1.14589 valid acc:0.75955
# Epoch:45 / 50, train loss:0.17976 train_acc:0.92611, valid loss:1.20305 valid acc:0.74826
# Epoch:46 / 50, train loss:0.16988 train_acc:0.92687, valid loss:1.17263 valid acc:0.75825
# Epoch:47 / 50, train loss:0.16596 train_acc:0.92741, valid loss:1.16410 valid acc:0.75608
# Epoch:48 / 50, train loss:0.16154 train_acc:0.92741, valid loss:1.18179 valid acc:0.75781
# Epoch:49 / 50, train loss:0.15437 train_acc:0.92990, valid loss:1.20368 valid acc:0.75825
# Epoch:50 / 50, train loss:0.14864 train_acc:0.92969, valid loss:1.19488 valid acc:0.75868

# %%
# Plot test loss curves
epochs = range(1, len(hista['train_loss']) + 1)

plt.plot(epochs, hista['test_loss'], 'r-', label='Model A')
plt.plot(epochs, histb['test_loss'], 'b-', label='Model B')
plt.plot(epochs, histc['test_loss'], 'g-', label='Model C')

plt.title('Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Test loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
# Plot test accuracy curves

epochs = range(1, len(hista['test_acc']) + 1)

plt.plot(epochs, hista['test_acc'], 'r-', label='Model A');
plt.plot(epochs, histb['test_acc'], 'b-', label='Model B');
plt.plot(epochs, histc['test_acc'], 'g-', label='Model C');

plt.title('Test Accuracy');
plt.xlabel('Epochs');
plt.ylabel('Accuracy');
plt.legend();

plt.show()
# Out:
# Text(0.5, 1.0, 'Test Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ### Q2: Fight overfitting
# - Take the `best model` you achieved from Q1 and add regularizers in order to reduce or at least delay overfitting without hurting its classification accuracy. You can consider the following strategies:
#     1. `dropout`: Add Dropout layers to input or hidden layers
#     2. `Batch Normalization`: Add Batch Normalization layers after hidden layers.
#     3. `L1/L2 Regularizer`: Add L2/L1 normal penality with appropriate coefficient.
#
#
# - Pick one or a combination of strategies and modify the model
#
#
# - Train the  model as in Q1
#
#
# - Plot test loss and test accuracy vs. epoches from the training histories of all the models.
#
#
# - Write your analysis (as markdowns) on the following:
#    - Are you able to find a good strategy to address overfitting in this case? If so, why do you think the strategy you used can be effective?
#    - What other strategies have you tried? Are they effective?
#    - Overall, through Q1 and Q2, can you summarize what you have learned regarding modeling and training?
#    - Note, this is an open question. Feel free to share you learning experience. We'll summarize all students' analyses and share them in class.
#
#
# A reference plot is provided. However, depending on the strategy you choose, you may get a different plot.

# %%
# Define model with regularizer
class linear_model_with_regularizer(nn.Module):
    
   # add your code here

# %%
# Train model with regularizer

# dataset
train_dataset = news_dataset(x_train, y_train)
test_dataset = news_dataset(x_test, y_test)

modeld = linear_model_with_regularizer()

summary(modeld, (24, 10000))

histd = train_model(modeld, train_dataset, test_dataset, 
                     device, epochs = 50)

# %%
# Plot validation loss curves
epochs = range(1, len(hista['train_loss']) + 1)

plt.plot(epochs, hista['test_loss'], 'r-', label='Model A')
plt.plot(epochs, histb['test_loss'], 'b-', label='Model B')
plt.plot(epochs, histc['test_loss'], 'g-', label='Model C')
plt.plot(epochs, histd['test_loss'], '-', color='purple', label='Model A with regularizer')

plt.title('Test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Test loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
# Plot validation accuracy curves
epochs = range(1, len(hista['test_acc']) + 1)

plt.plot(epochs, hista['test_acc'], 'r-', label='Model A');
plt.plot(epochs, histb['test_acc'], 'b-', label='Model B');
plt.plot(epochs, histc['test_acc'], 'g-', label='Model C');
plt.plot(epochs, histd['test_acc'], '-', color='purple', label='Model A with regularizer');

plt.title('Test Accuracy');
plt.xlabel('Epochs');
plt.ylabel('Accuracy');
plt.legend();

plt.show()

# %% [markdown]
# ### Q3 (Bonus): Imbalanced Dataset
#
# Here we have a very imbalance dataset. Many classes only have a few training samples. As a result, when you display the classification report (see below), you'll see precision/recall/f1 is very low for some classes.
#
# Assuming that it is very difficult to collect extra samples, could you think of one method to improve the peformance of some underpresented classes without hurting the overall performance?
#
# Implement your method and demonstrate the improvement you can achieve.
#
# Please describe your method as markdowns and explain why this method can address dataset skewness.

# %%
# Classification report of Model in Q2

print(classification_report(Y, P))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82        12
#            1       0.67      0.82      0.74       105
#            2       0.78      0.70      0.74        20
#            3       0.92      0.94      0.93       813
#            4       0.84      0.89      0.86       474
#            5       0.00      0.00      0.00         5
#            6       0.93      0.93      0.93        14
#            7       1.00      0.33      0.50         3
#            8       0.72      0.76      0.74        38
#            9       0.87      0.80      0.83        25
#           10       0.96      0.87      0.91        30
#           11       0.62      0.77      0.68        83
#           12       0.50      0.23      0.32        13
#           13       0.55      0.57      0.56        37
#           14       1.00      0.50      0.67         2
#           15       0.50      0.11      0.18         9
#           16       0.68      0.76      0.71        99
#           17       0.75      0.25      0.38        12
#           18       0.75      0.60      0.67        20
#           19       0.68      0.73      0.70       133
#           20       0.67      0.50      0.57        70
#           21       0.64      0.78      0.70        27
#           22       0.00      0.00      0.00         7
#           23       0.67      0.67      0.67        12
#           24       0.60      0.32      0.41        19
#           25       0.81      0.68      0.74        31
#           26       0.88      0.88      0.88         8
#           27       1.00      0.25      0.40         4
#           28       0.50      0.40      0.44        10
#           29       0.33      0.25      0.29         4
#           30       0.67      0.50      0.57        12
#           31       0.70      0.54      0.61        13
#           32       1.00      0.80      0.89        10
#           33       0.80      0.80      0.80         5
#           34       0.75      0.43      0.55         7
#           35       1.00      0.67      0.80         6
#           36       0.62      0.45      0.53        11
#           37       0.50      0.50      0.50         2
#           38       1.00      0.67      0.80         3
#           39       0.00      0.00      0.00         5
#           40       1.00      0.30      0.46        10
#           41       0.67      0.25      0.36         8
#           42       0.50      0.33      0.40         3
#           43       0.83      0.83      0.83         6
#           44       0.67      0.80      0.73         5
#           45       1.00      1.00      1.00         1
#
#     accuracy                           0.81      2246
#    macro avg       0.70      0.56      0.60      2246
# weighted avg       0.81      0.81      0.80      2246
