# %% [markdown]
# # Image Data Augmentation

# %% [markdown]
# Haohang Li
# 2021/10/18

# %% [markdown]
# ### Dependencies

# %%
! pip install torchinfo
! pip install gdown  # download large file from Google Drive
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.5.3-py3-none-any.whl (19 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.5.3
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (3.6.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.62.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gdown) (1.24.3)

# %%
import os
import shutil
import glob
import random
import concurrent
import zipfile
import torch
import PIL
import numpy as np
import torch.nn as nn
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split, Dataset
from IPython.display import Image
from torchinfo import summary

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Data

# %% [markdown]
# ### Download data & unzip:

# %%
! gdown https://drive.google.com/uc?id=1ItGv65UmiQKnett7vxY1qNPTXRg4hSfW
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ItGv65UmiQKnett7vxY1qNPTXRg4hSfW
# To: /content/dog_cat.zip
# 100% 570M/570M [00:06<00:00, 86.3MB/s]

# %%
with zipfile.ZipFile('/content/dog_cat.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %% [markdown]
# ### Re-organize data & generate small sample:

# %% [markdown]
# Dir structure:

# %%
# cwd
cwd = os.getcwd()
print(cwd)
# dirs
dog_cat_dir = os.path.join(cwd, 'dog_cat')
if not os.path.exists(dog_cat_dir):
    os.mkdir(dog_cat_dir)

cat_dir = os.path.join(dog_cat_dir, 'cat')
if not os.path.exists(cat_dir):
    os.mkdir(cat_dir)
    
dog_dir = os.path.join(dog_cat_dir, 'dog')
if not os.path.exists(dog_dir):
    os.mkdir(dog_dir)

# sample random 1000 pics for cats & dogs
cat_pics = np.random.choice(glob.glob(os.path.join(cwd, 'train', 'cat.*.jpg')), size=1000, replace=False)
dog_pics = np.random.choice(glob.glob(os.path.join(cwd, 'train', 'dog.*.jpg')), size=1000, replace=False)

# move to dir
def move_to_folder(scr_file, des_folder):
    des_name = os.path.basename(scr_file)
    shutil.copyfile(scr_file, os.path.join(des_folder, des_name))
# cats
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as pool:
    [pool.submit(move_to_folder, file_name, cat_dir) for file_name in cat_pics]
# dogs
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as pool:
    [pool.submit(move_to_folder, file_name, dog_dir) for file_name in dog_pics]
# Out:
# /content

# %%
print(os.listdir(cat_dir)[:10])
print(os.listdir(dog_dir)[:10])
# Out:
# ['cat.11494.jpg', 'cat.2688.jpg', 'cat.2876.jpg', 'cat.1365.jpg', 'cat.2244.jpg', 'cat.11672.jpg', 'cat.10269.jpg', 'cat.2443.jpg', 'cat.8453.jpg', 'cat.8763.jpg']
# ['dog.12272.jpg', 'dog.11851.jpg', 'dog.10009.jpg', 'dog.5278.jpg', 'dog.12273.jpg', 'dog.12318.jpg', 'dog.8033.jpg', 'dog.6208.jpg', 'dog.11353.jpg', 'dog.3919.jpg']

# %% [markdown]
# ### Show a cat and dog example

# %%
Image(os.path.join(cat_dir, os.listdir(cat_dir)[0]))

# %%
Image(os.path.join(dog_dir, os.listdir(dog_dir)[0]))

# %% [markdown]
# ## Define Model

# %%
class CNN_Classifier(nn.Module):
    def __init__(self):
        super(CNN_Classifier, self).__init__()
        # Conv net
        self.convnet = nn.Sequential(
            # input(3, 150, 150)
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3), # (32, 148, 148)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # (32, 74, 74)
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),  # (64, 72, 72)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # (64, 36, 36)
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3),  # (128, 34, 34)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # (128, 17, 17)
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3),  # (128, 15, 15)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # (128, 7, 7)
            nn.Flatten() # 6272 = 128 * 7 * 7
        )
        # classifier
        self.classifier = nn.Sequential(
            nn.Linear(in_features=6272, out_features=512),
            nn.ReLU(),
            nn.Linear(in_features=512, out_features=1)
        )
    
    def forward(self, x):
        x = self.convnet(x)
        x = self.classifier(x)

        return x

# %%
sample_model = CNN_Classifier()
summary(sample_model, (10, 3, 150, 150))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN_Classifier                           --                        --
# ├─Sequential: 1-1                        [10, 6272]                --
# │    └─Conv2d: 2-1                       [10, 32, 148, 148]        896
# │    └─ReLU: 2-2                         [10, 32, 148, 148]        --
# │    └─MaxPool2d: 2-3                    [10, 32, 74, 74]          --
# │    └─Conv2d: 2-4                       [10, 64, 72, 72]          18,496
# │    └─ReLU: 2-5                         [10, 64, 72, 72]          --
# │    └─MaxPool2d: 2-6                    [10, 64, 36, 36]          --
# │    └─Conv2d: 2-7                       [10, 128, 34, 34]         73,856
# │    └─ReLU: 2-8                         [10, 128, 34, 34]         --
# │    └─MaxPool2d: 2-9                    [10, 128, 17, 17]         --
# │    └─Conv2d: 2-10                      [10, 128, 15, 15]         147,584
# │    └─ReLU: 2-11                        [10, 128, 15, 15]         --
# │    └─MaxPool2d: 2-12                   [10, 128, 7, 7]           --
# │    └─Flatten: 2-13                     [10, 6272]                --
# ├─Sequential: 1-2                        [10, 1]                   --
# │    └─Linear: 2-14                      [10, 512]                 3,211,776
# │    └─ReLU: 2-15                        [10, 512]                 --
# │    └─Linear: 2-16                      [10, 1]                   513
# ==========================================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# Total mult-adds (G): 2.37
# ==========================================================================================
# Input size (MB): 2.70
# Forward/backward pass size (MB): 96.80
# Params size (MB): 13.81
# Estimated Total Size (MB): 113.31
# ==========================================================================================

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Self-defined Dataset:

# %%
class ImgDataset(Dataset):
    def __init__(self, img_path, img_labels, img_transforms=None):
        self.img_path = img_path
        self.img_labels = torch.Tensor(img_labels)
        if img_transforms is None:
            self.transforms = transforms.ToTensor()
        else:
            self.transforms = img_transforms
    
    def __getitem__(self, index):
        # load image
        cur_path = self.img_path[index] # mini batch
        cur_img = PIL.Image.open(cur_path)
        cur_img = self.transforms(cur_img)

        return cur_img, self.img_labels[index]
    
    def __len__(self):
        return len(self.img_path)

# %%
images_list = glob.glob(os.path.join(dog_cat_dir, '*', '*.jpg'))
# label: 0 for cat, 1 for dog
def extract_class(img_path):
    base_path = os.path.basename(img_path)
    return base_path.split('.')[0]

labels = [0 if extract_class(cur_path) == 'cat' else 1 for cur_path in images_list]

# %%
resize_transforms = transforms.Compose([transforms.Resize((150, 150)), transforms.ToTensor()])

# %%
dog_cat_dataset = ImgDataset(img_path=images_list, img_labels=labels, img_transforms=resize_transforms)

# %%
dog_cat_dataset[0]
# Out:
# (tensor([[[0.4000, 0.5176, 0.6235,  ..., 0.3059, 0.3608, 0.3647],
#           [0.4157, 0.4510, 0.4588,  ..., 0.3608, 0.3725, 0.3569],
#           [0.3686, 0.3765, 0.4196,  ..., 0.4039, 0.3608, 0.3451],
#           ...,
#           [0.4549, 0.3373, 0.2784,  ..., 0.5255, 0.4745, 0.3569],
#           [0.4431, 0.3529, 0.3176,  ..., 0.2039, 0.2706, 0.2157],
#           [0.3804, 0.2824, 0.3294,  ..., 0.2314, 0.3020, 0.3137]],
#
#          [[0.3961, 0.5020, 0.6118,  ..., 0.3255, 0.3804, 0.3804],
#           [0.4471, 0.4745, 0.4745,  ..., 0.3843, 0.4118, 0.4118],
#           [0.4275, 0.4314, 0.4667,  ..., 0.4235, 0.3961, 0.4039],
#           ...,
#           [0.3882, 0.2824, 0.2353,  ..., 0.4118, 0.3569, 0.2431],
#           [0.3686, 0.2863, 0.2706,  ..., 0.1059, 0.1608, 0.1098],
#           [0.3294, 0.2157, 0.2471,  ..., 0.1843, 0.2000, 0.1725]],
#
#          [[0.2588, 0.4157, 0.5216,  ..., 0.0863, 0.1373, 0.1529],
#           [0.2549, 0.3176, 0.3294,  ..., 0.1529, 0.1608, 0.1529],
#           [0.1882, 0.1961, 0.2510,  ..., 0.2196, 0.1686, 0.1490],
#           ...,
#           [0.3490, 0.2275, 0.1608,  ..., 0.4000, 0.3451, 0.2314],
#           [0.3490, 0.2471, 0.2000,  ..., 0.1020, 0.1608, 0.1020],
#           [0.2941, 0.1686, 0.1843,  ..., 0.1608, 0.1804, 0.1569]]]),
#  tensor(1.))

# %% [markdown]
# ### ImageFolder:

# %%
from torchvision.datasets import ImageFolder
dog_cat_dataset_folder = ImageFolder(dog_cat_dir, transform=transforms.ToTensor())

# %%
dog_cat_dataset_folder[0]
# Out:
# (tensor([[[0.9255, 0.9255, 0.9294,  ..., 0.8353, 0.8314, 0.8314],
#           [0.9255, 0.9294, 0.9294,  ..., 0.8275, 0.8235, 0.8235],
#           [0.9255, 0.9294, 0.9333,  ..., 0.8431, 0.8392, 0.8392],
#           ...,
#           [0.7843, 0.8118, 0.8549,  ..., 0.9059, 0.9059, 0.9137],
#           [0.7922, 0.8078, 0.8353,  ..., 0.9294, 0.9255, 0.9294],
#           [0.8275, 0.8235, 0.8353,  ..., 0.9216, 0.9255, 0.9216]],
#
#          [[0.5882, 0.5882, 0.5922,  ..., 0.6706, 0.6745, 0.6745],
#           [0.5882, 0.5922, 0.5922,  ..., 0.6627, 0.6667, 0.6667],
#           [0.5882, 0.5922, 0.5961,  ..., 0.6784, 0.6824, 0.6824],
#           ...,
#           [0.3686, 0.3843, 0.3961,  ..., 0.5569, 0.5569, 0.5647],
#           [0.3647, 0.3686, 0.3725,  ..., 0.5725, 0.5765, 0.5804],
#           [0.3961, 0.3765, 0.3725,  ..., 0.5647, 0.5686, 0.5765]],
#
#          [[0.5843, 0.5843, 0.5882,  ..., 0.7176, 0.7176, 0.7176],
#           [0.5843, 0.5882, 0.5882,  ..., 0.7098, 0.7098, 0.7098],
#           [0.5843, 0.5882, 0.5922,  ..., 0.7255, 0.7255, 0.7255],
#           ...,
#           [0.1333, 0.1294, 0.1216,  ..., 0.2980, 0.2980, 0.3059],
#           [0.1333, 0.1176, 0.0980,  ..., 0.2980, 0.3020, 0.3059],
#           [0.1647, 0.1294, 0.0980,  ..., 0.2863, 0.2902, 0.2941]]]), 0)

# %% [markdown]
# ### Split Dataset

# %%
split_size = (np.array([0.6, 0.2, 0.2]) * len(dog_cat_dataset)).round().astype(np.int)
train_data, valid_data, test_data = random_split(dog_cat_dataset, split_size)

# %% [markdown]
# ## Train Function

# %%
def train_model(model, train_dataset, test_dataset, device, 
                lr=0.0001, epochs=30, batch_size=256):
    
    # construct dataloader
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # move model to device
    model = model.to(device)

    # history
    history = {'train_loss': [],
               'train_acc': [],
               'test_loss': [],
               'test_acc': []}
    # setup loss function and optimizer
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.RMSprop(model.parameters(), lr=lr)
    # training loop
    print('Training Start')
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        test_loss = 0
        test_acc = 0
        
        for x, y in train_loader:
            # move data to device
            x = x.to(device)
            y = y.to(device)
            # forward
            outputs = model(x).view(-1)  # (num_batch)
            cur_train_loss = criterion(outputs, y)
            pred = torch.sigmoid(outputs)
            pred = torch.round(pred)
            cur_train_acc = (pred == y).sum().item() / batch_size
            # backward
            cur_train_loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            # loss and acc
            train_loss += cur_train_loss
            train_acc += cur_train_acc

        # test start
        model.eval()
        with torch.no_grad():
            for x, y in test_loader:
                # move
                x = x.to(device)
                y = y.to(device)
                # predict
                outputs = model(x).view(-1)
                pred = torch.round(torch.sigmoid(outputs))
                cur_test_loss = criterion(outputs, y)
                cur_test_acc = (pred == y).sum().item() / batch_size 
                # loss and acc
                test_loss += cur_test_loss
                test_acc += cur_test_acc

        # epoch output
        train_loss = (train_loss/len(train_loader)).item()
        train_acc = train_acc/len(train_loader)
        val_loss = (test_loss/len(test_loader)).item()
        val_acc = test_acc/len(test_loader)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(val_loss)
        history['test_acc'].append(val_acc)
        print(f"Epoch:{epoch + 1} / {epochs}, train loss:{train_loss:.4f} train_acc:{train_acc:.4f}, valid loss:{val_loss:.4f} valid acc:{val_acc:.4f}")
    
    return history

# %% [markdown]
# ## Train Model

# %%
cnn_model = CNN_Classifier()

# %%
history = train_model(cnn_model, train_data, valid_data, device, batch_size=32, epochs=30, lr=0.0001)
# Out:
# Training Start
# Epoch:1 / 30, train loss:0.6945 train_acc:0.5074, valid loss:0.6838 valid acc:0.5938
# Epoch:2 / 30, train loss:0.6857 train_acc:0.5535, valid loss:0.6678 valid acc:0.5938
# Epoch:3 / 30, train loss:0.6711 train_acc:0.5806, valid loss:0.6537 valid acc:0.6298
# Epoch:4 / 30, train loss:0.6632 train_acc:0.5806, valid loss:0.6443 valid acc:0.6178
# Epoch:5 / 30, train loss:0.6560 train_acc:0.6028, valid loss:0.6564 valid acc:0.6058
# Epoch:6 / 30, train loss:0.6463 train_acc:0.6258, valid loss:0.6310 valid acc:0.6394
# Epoch:7 / 30, train loss:0.6372 train_acc:0.6184, valid loss:0.7488 valid acc:0.5120
# Epoch:8 / 30, train loss:0.6289 train_acc:0.6340, valid loss:0.6132 valid acc:0.6659
# Epoch:9 / 30, train loss:0.6153 train_acc:0.6513, valid loss:0.6214 valid acc:0.6202
# Epoch:10 / 30, train loss:0.5980 train_acc:0.6637, valid loss:0.6124 valid acc:0.6731
# Epoch:11 / 30, train loss:0.5914 train_acc:0.6801, valid loss:0.6352 valid acc:0.6178
# Epoch:12 / 30, train loss:0.5753 train_acc:0.6883, valid loss:0.5851 valid acc:0.6803
# Epoch:13 / 30, train loss:0.5623 train_acc:0.7064, valid loss:0.5839 valid acc:0.6923
# Epoch:14 / 30, train loss:0.5503 train_acc:0.6982, valid loss:0.6165 valid acc:0.6659
# Epoch:15 / 30, train loss:0.5344 train_acc:0.7204, valid loss:0.6012 valid acc:0.6707
# Epoch:16 / 30, train loss:0.5316 train_acc:0.7204, valid loss:0.5820 valid acc:0.6635
# Epoch:17 / 30, train loss:0.5186 train_acc:0.7212, valid loss:0.5900 valid acc:0.6923
# Epoch:18 / 30, train loss:0.5064 train_acc:0.7475, valid loss:0.5494 valid acc:0.7091
# Epoch:19 / 30, train loss:0.4831 train_acc:0.7525, valid loss:0.6415 valid acc:0.6466
# Epoch:20 / 30, train loss:0.4812 train_acc:0.7549, valid loss:0.5458 valid acc:0.7067
# Epoch:21 / 30, train loss:0.4841 train_acc:0.7689, valid loss:0.6409 valid acc:0.6274
# Epoch:22 / 30, train loss:0.4678 train_acc:0.7656, valid loss:0.5186 valid acc:0.6971
# Epoch:23 / 30, train loss:0.4560 train_acc:0.7623, valid loss:0.5707 valid acc:0.7091
# Epoch:24 / 30, train loss:0.4509 train_acc:0.7730, valid loss:0.5310 valid acc:0.6779
# Epoch:25 / 30, train loss:0.4479 train_acc:0.7862, valid loss:0.5547 valid acc:0.6755
# Epoch:26 / 30, train loss:0.4286 train_acc:0.7961, valid loss:0.5576 valid acc:0.7139
# Epoch:27 / 30, train loss:0.4196 train_acc:0.7936, valid loss:0.9226 valid acc:0.5577
# Epoch:28 / 30, train loss:0.4347 train_acc:0.7870, valid loss:0.5278 valid acc:0.7067
# Epoch:29 / 30, train loss:0.4060 train_acc:0.8059, valid loss:0.5748 valid acc:0.7043
# Epoch:30 / 30, train loss:0.4022 train_acc:0.7985, valid loss:0.5126 valid acc:0.7043

# %%
plt.plot(range(1, 31), history['train_acc'], label='Train')
plt.plot(range(1, 31), history['test_acc'], label='Valid')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(range(1, 31), history['train_loss'], label='Train')
plt.plot(range(1, 31), history['test_loss'], label='Valid')
plt.title('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Image Data Augmentation

# %% [markdown]
# The image transformations are implemented in [torchvision](https://pytorch.org/vision/stable/index.html). Some useful data augmentations:
#
# *   [torchvision.transforms.ColorJitter](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.ColorJitter): Randomly change the brightness, contrast, saturation and hue of an image.
# *   [torchvision.transforms.RandomHorizontalFlip](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.RandomHorizontalFlip) & [torchvision.transforms.RandomVerticalFlip](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.RandomVerticalFlip): Horizontally or vertically flip the given image randomly with a given probability.
# *   [torchvision.transforms.RandomGrayscale(p=0.1)](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.RandomGrayscale): Randomly convert image to grayscale with a a probability.
# *   [RandomRotation](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.RandomRotation): Randomly rotate images within certain degrees.

# %% [markdown]
# For the full list of availabe tranformations, please see [this](https://pytorch.org/vision/stable/transforms.html#torchvision.transforms.RandomRotation). The illustrations of transformations are available [here](https://pytorch.org/vision/stable/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py).

# %% [markdown]
# ### Image Transformation Example

# %%
# get a sample image
sample_img_path = os.path.join(cat_dir, os.listdir(cat_dir)[4])
sample_img = PIL.Image.open(sample_img_path)
display(sample_img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x335 at 0x7F28DA343AD0>

# %%
# apply random color jitter
transformed_img = transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0.5, hue=0.5)(sample_img)
display(transformed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x335 at 0x7F28D8431210>

# %%
transformed_img = transforms.RandomGrayscale(p=1.0)(sample_img)
display(transformed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x335 at 0x7F28D8428A10>

# %%
transformed_img = transforms.RandomHorizontalFlip(p=1.0)(sample_img)
display(transformed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x335 at 0x7F28D88C7B90>

# %%
# Chain the transformations to a pipeline
transform_pipeline = transforms.Compose(
    [transforms.RandomGrayscale(p=1.0), 
     transforms.RandomHorizontalFlip(p=1.0)])

transformed_img = transform_pipeline(sample_img)
display(transformed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x335 at 0x7F28D8431310>

# %% [markdown]
# ### Apply Transfoamation on Dataset

# %%
class ImgDataset(Dataset):
    def __init__(self, img_path, img_labels, img_transforms=None):
        self.img_path = img_path
        self.img_labels = torch.Tensor(img_labels)
        if img_transforms is None:
            self.transforms = transforms.ToTensor()
        else:
            self.transforms = img_transforms
    
    def __getitem__(self, index):
        # load image
        cur_path = self.img_path[index]
        cur_img = PIL.Image.open(cur_path)
        cur_img = self.transforms(cur_img)

        return cur_img, self.img_labels[index]
    
    def __len__(self):
        return len(self.img_path)

# %% [markdown]
# Build a transformation pipeline:

# %%
transformations = transforms.Compose([transforms.Resize((150, 150)),  # resize to input shape of our CNN
                                      transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.3),
                                      transforms.RandomRotation(40),
                                      transforms.RandomAffine(degrees=0, scale=(0.8, 1.2), shear=0.2),
                                      transforms.RandomHorizontalFlip(p=0.5),
                                      transforms.ToTensor()  # convert PIL to Tensor
                                      ])

# %% [markdown]
# New dataset with transformation pipline:

# %%
dog_cat_dataset_transformed = ImgDataset(img_path=images_list, img_labels=labels, img_transforms=transformations)

split_size = (np.array([0.6, 0.2, 0.2]) * len(dog_cat_dataset_transformed)).round().astype(np.int)
train_data, valid_data, test_data = random_split(dog_cat_dataset_transformed, split_size)

# %% [markdown]
# ### Re-Train CNN Model:

# %%
cnn_model = CNN_Classifier()

# %%
history = train_model(cnn_model, train_data, valid_data, device, batch_size=32, epochs=150, lr=0.0001)
# Out:
# Training Start
# Epoch:1 / 150, train loss:0.6972 train_acc:0.5214, valid loss:0.6876 valid acc:0.5433
# Epoch:2 / 150, train loss:0.6860 train_acc:0.5559, valid loss:0.6814 valid acc:0.5625
# Epoch:3 / 150, train loss:0.6813 train_acc:0.5658, valid loss:0.6756 valid acc:0.5649
# Epoch:4 / 150, train loss:0.6781 train_acc:0.5551, valid loss:0.6879 valid acc:0.5312
# Epoch:5 / 150, train loss:0.6777 train_acc:0.5658, valid loss:0.6781 valid acc:0.5096
# Epoch:6 / 150, train loss:0.6748 train_acc:0.5674, valid loss:0.6672 valid acc:0.5938
# Epoch:7 / 150, train loss:0.6661 train_acc:0.5880, valid loss:0.6892 valid acc:0.5168
# Epoch:8 / 150, train loss:0.6690 train_acc:0.6086, valid loss:0.6688 valid acc:0.5721
# Epoch:9 / 150, train loss:0.6636 train_acc:0.5954, valid loss:0.6842 valid acc:0.5337
# Epoch:10 / 150, train loss:0.6534 train_acc:0.6069, valid loss:0.7007 valid acc:0.5120
# Epoch:11 / 150, train loss:0.6492 train_acc:0.6160, valid loss:0.6824 valid acc:0.5529
# Epoch:12 / 150, train loss:0.6477 train_acc:0.6225, valid loss:0.6686 valid acc:0.5625
# Epoch:13 / 150, train loss:0.6508 train_acc:0.6250, valid loss:0.6723 valid acc:0.5865
# Epoch:14 / 150, train loss:0.6442 train_acc:0.6242, valid loss:0.6509 valid acc:0.5841
# Epoch:15 / 150, train loss:0.6315 train_acc:0.6299, valid loss:0.6520 valid acc:0.5745
# Epoch:16 / 150, train loss:0.6287 train_acc:0.6472, valid loss:0.6493 valid acc:0.6010
# Epoch:17 / 150, train loss:0.6310 train_acc:0.6316, valid loss:0.6742 valid acc:0.5769
# Epoch:18 / 150, train loss:0.6283 train_acc:0.6283, valid loss:0.6407 valid acc:0.6082
# Epoch:19 / 150, train loss:0.6261 train_acc:0.6464, valid loss:0.6530 valid acc:0.6178
# Epoch:20 / 150, train loss:0.6131 train_acc:0.6488, valid loss:0.6159 valid acc:0.6226
# Epoch:21 / 150, train loss:0.6166 train_acc:0.6480, valid loss:0.6290 valid acc:0.6178
# Epoch:22 / 150, train loss:0.6179 train_acc:0.6464, valid loss:0.6151 valid acc:0.6322
# Epoch:23 / 150, train loss:0.6050 train_acc:0.6785, valid loss:0.6476 valid acc:0.6034
# Epoch:24 / 150, train loss:0.6072 train_acc:0.6669, valid loss:0.6416 valid acc:0.6106
# Epoch:25 / 150, train loss:0.5956 train_acc:0.6735, valid loss:0.6526 valid acc:0.6130
# Epoch:26 / 150, train loss:0.6023 train_acc:0.6678, valid loss:0.6194 valid acc:0.6226
# Epoch:27 / 150, train loss:0.5958 train_acc:0.6752, valid loss:0.7163 valid acc:0.5889
# Epoch:28 / 150, train loss:0.5940 train_acc:0.6661, valid loss:0.6622 valid acc:0.5769
# Epoch:29 / 150, train loss:0.5988 train_acc:0.6826, valid loss:0.6903 valid acc:0.5817
# Epoch:30 / 150, train loss:0.5927 train_acc:0.6760, valid loss:0.6455 valid acc:0.5962
# Epoch:31 / 150, train loss:0.5976 train_acc:0.6735, valid loss:0.6399 valid acc:0.5913
# Epoch:32 / 150, train loss:0.5824 train_acc:0.6801, valid loss:0.5905 valid acc:0.6514
# Epoch:33 / 150, train loss:0.5716 train_acc:0.6891, valid loss:0.6222 valid acc:0.6058
# Epoch:34 / 150, train loss:0.5784 train_acc:0.6982, valid loss:0.5958 valid acc:0.6635
# Epoch:35 / 150, train loss:0.5798 train_acc:0.6875, valid loss:0.6072 valid acc:0.6274
# Epoch:36 / 150, train loss:0.5638 train_acc:0.7007, valid loss:0.6507 valid acc:0.6202
# Epoch:37 / 150, train loss:0.5705 train_acc:0.6924, valid loss:0.7127 valid acc:0.5697
# Epoch:38 / 150, train loss:0.5694 train_acc:0.6990, valid loss:0.6291 valid acc:0.6106
# Epoch:39 / 150, train loss:0.5596 train_acc:0.6908, valid loss:0.5796 valid acc:0.6394
# Epoch:40 / 150, train loss:0.5687 train_acc:0.7163, valid loss:0.6177 valid acc:0.6659
# Epoch:41 / 150, train loss:0.5613 train_acc:0.6982, valid loss:0.6011 valid acc:0.6538
# Epoch:42 / 150, train loss:0.5645 train_acc:0.7105, valid loss:0.6106 valid acc:0.6394
# Epoch:43 / 150, train loss:0.5548 train_acc:0.7064, valid loss:0.6244 valid acc:0.6370
# Epoch:44 / 150, train loss:0.5665 train_acc:0.6998, valid loss:0.6083 valid acc:0.6250
# Epoch:45 / 150, train loss:0.5481 train_acc:0.7138, valid loss:0.6255 valid acc:0.6394
# Epoch:46 / 150, train loss:0.5658 train_acc:0.7031, valid loss:0.6053 valid acc:0.6394
# Epoch:47 / 150, train loss:0.5432 train_acc:0.7237, valid loss:0.6144 valid acc:0.6370
# Epoch:48 / 150, train loss:0.5562 train_acc:0.7138, valid loss:0.5886 valid acc:0.6538
# Epoch:49 / 150, train loss:0.5616 train_acc:0.6957, valid loss:0.5722 valid acc:0.6635
# Epoch:50 / 150, train loss:0.5346 train_acc:0.7286, valid loss:0.6394 valid acc:0.6034
# Epoch:51 / 150, train loss:0.5364 train_acc:0.7237, valid loss:0.6006 valid acc:0.6226
# Epoch:52 / 150, train loss:0.5443 train_acc:0.7188, valid loss:0.5961 valid acc:0.6587
# Epoch:53 / 150, train loss:0.5556 train_acc:0.7072, valid loss:0.5893 valid acc:0.6587
# Epoch:54 / 150, train loss:0.5391 train_acc:0.7212, valid loss:0.6809 valid acc:0.6058
# Epoch:55 / 150, train loss:0.5265 train_acc:0.7286, valid loss:0.5866 valid acc:0.6370
# Epoch:56 / 150, train loss:0.5334 train_acc:0.7278, valid loss:0.5665 valid acc:0.6755
# Epoch:57 / 150, train loss:0.5235 train_acc:0.7319, valid loss:0.5777 valid acc:0.6827
# Epoch:58 / 150, train loss:0.5275 train_acc:0.7270, valid loss:0.6464 valid acc:0.6250
# Epoch:59 / 150, train loss:0.5176 train_acc:0.7204, valid loss:0.5915 valid acc:0.6587
# Epoch:60 / 150, train loss:0.5347 train_acc:0.7319, valid loss:0.6121 valid acc:0.6082
# Epoch:61 / 150, train loss:0.5160 train_acc:0.7492, valid loss:0.5928 valid acc:0.6442
# Epoch:62 / 150, train loss:0.5260 train_acc:0.7303, valid loss:0.6120 valid acc:0.6274
# Epoch:63 / 150, train loss:0.5263 train_acc:0.7278, valid loss:0.6082 valid acc:0.6370
# Epoch:64 / 150, train loss:0.5180 train_acc:0.7278, valid loss:0.5642 valid acc:0.6635
# Epoch:65 / 150, train loss:0.5041 train_acc:0.7385, valid loss:0.5670 valid acc:0.6899
# Epoch:66 / 150, train loss:0.5143 train_acc:0.7352, valid loss:0.5952 valid acc:0.6779
# Epoch:67 / 150, train loss:0.5113 train_acc:0.7459, valid loss:0.5714 valid acc:0.6683
# Epoch:68 / 150, train loss:0.5088 train_acc:0.7484, valid loss:0.5705 valid acc:0.6827
# Epoch:69 / 150, train loss:0.5149 train_acc:0.7360, valid loss:0.6062 valid acc:0.6514
# Epoch:70 / 150, train loss:0.5197 train_acc:0.7377, valid loss:0.6093 valid acc:0.6490
# Epoch:71 / 150, train loss:0.5127 train_acc:0.7418, valid loss:0.6129 valid acc:0.6538
# Epoch:72 / 150, train loss:0.5069 train_acc:0.7253, valid loss:0.5673 valid acc:0.6418
# Epoch:73 / 150, train loss:0.5016 train_acc:0.7393, valid loss:0.6200 valid acc:0.6274
# Epoch:74 / 150, train loss:0.4915 train_acc:0.7442, valid loss:0.5493 valid acc:0.6851
# Epoch:75 / 150, train loss:0.5042 train_acc:0.7451, valid loss:0.5574 valid acc:0.6923
# Epoch:76 / 150, train loss:0.4884 train_acc:0.7410, valid loss:0.5450 valid acc:0.6731
# Epoch:77 / 150, train loss:0.5155 train_acc:0.7377, valid loss:0.5949 valid acc:0.6346
# Epoch:78 / 150, train loss:0.4850 train_acc:0.7664, valid loss:0.5479 valid acc:0.6827
# Epoch:79 / 150, train loss:0.4923 train_acc:0.7549, valid loss:0.5880 valid acc:0.6899
# Epoch:80 / 150, train loss:0.4836 train_acc:0.7590, valid loss:0.5502 valid acc:0.6851
# Epoch:81 / 150, train loss:0.4833 train_acc:0.7599, valid loss:0.5181 valid acc:0.7091
# Epoch:82 / 150, train loss:0.4956 train_acc:0.7492, valid loss:0.5435 valid acc:0.6779
# Epoch:83 / 150, train loss:0.4895 train_acc:0.7500, valid loss:0.5407 valid acc:0.6851
# Epoch:84 / 150, train loss:0.4631 train_acc:0.7673, valid loss:0.5626 valid acc:0.6875
# Epoch:85 / 150, train loss:0.4824 train_acc:0.7656, valid loss:0.5942 valid acc:0.6442
# Epoch:86 / 150, train loss:0.4799 train_acc:0.7549, valid loss:0.5807 valid acc:0.6683
# Epoch:87 / 150, train loss:0.4739 train_acc:0.7689, valid loss:0.5948 valid acc:0.6755
# Epoch:88 / 150, train loss:0.4891 train_acc:0.7607, valid loss:0.5827 valid acc:0.6923
# Epoch:89 / 150, train loss:0.4656 train_acc:0.7804, valid loss:0.6045 valid acc:0.6514
# Epoch:90 / 150, train loss:0.4872 train_acc:0.7467, valid loss:0.6788 valid acc:0.6322
# Epoch:91 / 150, train loss:0.4661 train_acc:0.7623, valid loss:0.5748 valid acc:0.6731
# Epoch:92 / 150, train loss:0.4575 train_acc:0.7771, valid loss:0.5773 valid acc:0.6827
# Epoch:93 / 150, train loss:0.4751 train_acc:0.7607, valid loss:0.5399 valid acc:0.7067
# Epoch:94 / 150, train loss:0.4716 train_acc:0.7771, valid loss:0.5277 valid acc:0.6971
# Epoch:95 / 150, train loss:0.4665 train_acc:0.7771, valid loss:0.5758 valid acc:0.6851
# Epoch:96 / 150, train loss:0.4702 train_acc:0.7656, valid loss:0.5334 valid acc:0.6971
# Epoch:97 / 150, train loss:0.4593 train_acc:0.7689, valid loss:0.6118 valid acc:0.6418
# Epoch:98 / 150, train loss:0.4690 train_acc:0.7500, valid loss:0.5161 valid acc:0.7019
# Epoch:99 / 150, train loss:0.4706 train_acc:0.7541, valid loss:0.5276 valid acc:0.6971
# Epoch:100 / 150, train loss:0.4576 train_acc:0.7697, valid loss:0.5233 valid acc:0.7139
# Epoch:101 / 150, train loss:0.4656 train_acc:0.7566, valid loss:0.5371 valid acc:0.6995
# Epoch:102 / 150, train loss:0.4483 train_acc:0.7845, valid loss:0.5506 valid acc:0.7067
# Epoch:103 / 150, train loss:0.4581 train_acc:0.7673, valid loss:0.6378 valid acc:0.6466
# Epoch:104 / 150, train loss:0.4659 train_acc:0.7730, valid loss:0.5993 valid acc:0.6707
# Epoch:105 / 150, train loss:0.4483 train_acc:0.7755, valid loss:0.5503 valid acc:0.7043
# Epoch:106 / 150, train loss:0.4495 train_acc:0.7829, valid loss:0.4999 valid acc:0.7139
# Epoch:107 / 150, train loss:0.4510 train_acc:0.7763, valid loss:0.5676 valid acc:0.6635
# Epoch:108 / 150, train loss:0.4448 train_acc:0.7788, valid loss:0.5373 valid acc:0.6875
# Epoch:109 / 150, train loss:0.4534 train_acc:0.7862, valid loss:0.5721 valid acc:0.6947
# Epoch:110 / 150, train loss:0.4525 train_acc:0.7706, valid loss:0.5590 valid acc:0.6923
# Epoch:111 / 150, train loss:0.4538 train_acc:0.7854, valid loss:0.5397 valid acc:0.7163
# Epoch:112 / 150, train loss:0.4524 train_acc:0.7640, valid loss:0.4958 valid acc:0.7212
# Epoch:113 / 150, train loss:0.4613 train_acc:0.7648, valid loss:0.5620 valid acc:0.6779
# Epoch:114 / 150, train loss:0.4398 train_acc:0.7845, valid loss:0.5477 valid acc:0.7019
# Epoch:115 / 150, train loss:0.4177 train_acc:0.8010, valid loss:0.6144 valid acc:0.6635
# Epoch:116 / 150, train loss:0.4359 train_acc:0.7952, valid loss:0.5657 valid acc:0.6635
# Epoch:117 / 150, train loss:0.4438 train_acc:0.7738, valid loss:0.5404 valid acc:0.6899
# Epoch:118 / 150, train loss:0.4433 train_acc:0.7812, valid loss:0.6487 valid acc:0.6250
# Epoch:119 / 150, train loss:0.4398 train_acc:0.7837, valid loss:0.5259 valid acc:0.7043
# Epoch:120 / 150, train loss:0.4329 train_acc:0.7845, valid loss:0.5703 valid acc:0.6923
# Epoch:121 / 150, train loss:0.4255 train_acc:0.7936, valid loss:0.5149 valid acc:0.7115
# Epoch:122 / 150, train loss:0.4217 train_acc:0.7862, valid loss:0.5698 valid acc:0.6875
# Epoch:123 / 150, train loss:0.4197 train_acc:0.7919, valid loss:0.5071 valid acc:0.7163
# Epoch:124 / 150, train loss:0.4223 train_acc:0.7878, valid loss:0.5528 valid acc:0.6923
# Epoch:125 / 150, train loss:0.4133 train_acc:0.7977, valid loss:0.4939 valid acc:0.7332
# Epoch:126 / 150, train loss:0.4240 train_acc:0.7854, valid loss:0.5654 valid acc:0.7115
# Epoch:127 / 150, train loss:0.4182 train_acc:0.7961, valid loss:0.5092 valid acc:0.7308
# Epoch:128 / 150, train loss:0.4310 train_acc:0.7829, valid loss:0.4640 valid acc:0.7308
# Epoch:129 / 150, train loss:0.4286 train_acc:0.8002, valid loss:0.5196 valid acc:0.7163
# Epoch:130 / 150, train loss:0.4216 train_acc:0.7961, valid loss:0.5535 valid acc:0.6851
# Epoch:131 / 150, train loss:0.4186 train_acc:0.7952, valid loss:0.5294 valid acc:0.7067
# Epoch:132 / 150, train loss:0.4089 train_acc:0.8002, valid loss:0.6102 valid acc:0.6683
# Epoch:133 / 150, train loss:0.4183 train_acc:0.7895, valid loss:0.5240 valid acc:0.7163
# Epoch:134 / 150, train loss:0.3975 train_acc:0.8076, valid loss:0.5666 valid acc:0.6707
# Epoch:135 / 150, train loss:0.4155 train_acc:0.7944, valid loss:0.5503 valid acc:0.6923
# Epoch:136 / 150, train loss:0.4158 train_acc:0.7887, valid loss:0.5648 valid acc:0.6899
# Epoch:137 / 150, train loss:0.3993 train_acc:0.8158, valid loss:0.6372 valid acc:0.6611
# Epoch:138 / 150, train loss:0.4093 train_acc:0.8026, valid loss:0.5415 valid acc:0.7139
# Epoch:139 / 150, train loss:0.4184 train_acc:0.7985, valid loss:0.5429 valid acc:0.7115
# Epoch:140 / 150, train loss:0.3963 train_acc:0.8109, valid loss:0.5447 valid acc:0.7043
# Epoch:141 / 150, train loss:0.4080 train_acc:0.8076, valid loss:0.5172 valid acc:0.7356
# Epoch:142 / 150, train loss:0.4035 train_acc:0.8018, valid loss:0.4923 valid acc:0.7356
# Epoch:143 / 150, train loss:0.4080 train_acc:0.7993, valid loss:0.4966 valid acc:0.7332
# Epoch:144 / 150, train loss:0.4051 train_acc:0.8010, valid loss:0.5016 valid acc:0.7188
# Epoch:145 / 150, train loss:0.3941 train_acc:0.8191, valid loss:0.5012 valid acc:0.7236
# Epoch:146 / 150, train loss:0.3816 train_acc:0.8232, valid loss:0.5154 valid acc:0.7284
# Epoch:147 / 150, train loss:0.4017 train_acc:0.8043, valid loss:0.7120 valid acc:0.6731
# Epoch:148 / 150, train loss:0.3890 train_acc:0.8232, valid loss:0.4978 valid acc:0.7163
# Epoch:149 / 150, train loss:0.4039 train_acc:0.8043, valid loss:0.5030 valid acc:0.7524
# Epoch:150 / 150, train loss:0.4008 train_acc:0.7993, valid loss:0.4998 valid acc:0.7067

# %%
plt.plot(range(1, 151), history['train_acc'], label='Train')
plt.plot(range(1, 151), history['test_acc'], label='Valid')
plt.title('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(range(1, 151), history['train_loss'], label='Train')
plt.plot(range(1, 151), history['test_loss'], label='Valid')
plt.title('Loss')
plt.legend()
plt.show()

# %%
# image net  -> paper, help in picking optimum augmentation
