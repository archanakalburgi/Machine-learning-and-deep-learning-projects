# %%
! pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.5.4-py3-none-any.whl (19 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.5.4

# %%
import os
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import numpy as np

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report

from numpy.random import seed
import torch

from torchinfo import summary
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load MINST Dataset

# %% [markdown]
# Download the benchmark dataset MNIST from “http://yann.lecun.com/exdb/mnist/”. Implement multiclass logistic regression and try it on MNIST.

# %%
train_dataset = torchvision.datasets.MNIST('./data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

test_dataset = torchvision.datasets.MNIST('./data',
                                          train=False,
                                          transform=transforms.ToTensor(),
                                          download=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=128,
                          shuffle=True)
test_loader = DataLoader(dataset=test_dataset,
                          batch_size=128,
                          shuffle=False)

# %%
# train: 1 mini batch contains 128 observations
train_iterator = train_loader.__iter__()
train_sample_image, train_sample_label = next(train_iterator)

# test: 1 mini batch contains 128 observations
valid_iterator = test_loader.__iter__()
valid_sample_image, valid_sample_label = next(valid_iterator)

# print
print('Train Sample')
print('1 of 128 train sample', train_sample_image.shape)
print('1 of 128 train label', train_sample_label.shape)
print('Test Sample')
print('1 of 128 test sample', valid_sample_image.shape)
print('1 of 128 test label', valid_sample_label.shape)
# Out:
# Train Sample
# 1 of 128 train sample torch.Size([128, 1, 28, 28])
# 1 of 128 train label torch.Size([128])
# Test Sample
# 1 of 128 test sample torch.Size([128, 1, 28, 28])
# 1 of 128 test label torch.Size([128])

# %%
train_sample_image[1].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# ## Visualize data

# %%
fig = plt.figure()
cur_data, cur_label = train_dataset[0]
plt.subplot(2,3,0+1)
plt.tight_layout()
plt.imshow(cur_data[0], cmap='gray', interpolation='none')
plt.title("Ground Truth: {}".format(cur_label))
plt.xticks([])
plt.yticks([])
# Out:
# Text(0.5, 1.0, 'Ground Truth: 5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Three - layer feedforward network

# %%
class FeedForward(nn.Module):  
    def __init__(self, p, hidden_l1, hidden_l2):  
        super(FeedForward, self).__init__()  
        self.classifier = nn.Sequential(
            nn.Dropout(p=p),
            nn.Linear(in_features=784, out_features=hidden_l1),  
            nn.ReLU(),
            nn.Linear(in_features=hidden_l1, out_features=hidden_l2),
            nn.ReLU(),
            nn.Linear(in_features=hidden_l2, out_features=10)
        )
    def forward(self, x):
        x = x.reshape(-1, 28 * 28).to(device)
        x = self.classifier(x)

        return x

# %%
visual_model = FeedForward(p=0,hidden_l1=500,hidden_l2=500)
visual_model
# Out:
# FeedForward(
#   (classifier): Sequential(
#     (0): Dropout(p=0, inplace=False)
#     (1): Linear(in_features=784, out_features=500, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=500, out_features=500, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=500, out_features=10, bias=True)
#   )
# )

# %%
import numpy as np
import torch

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            # self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
def train_model(model, train_dataset, test_dataset, device, 
                lr=0.0001, epochs=30, batch_size=32, weight_decay=0):

    # move model to device
    model = model.to(device)
    early_stopping = EarlyStopping(patience=5, verbose=True)

    # history
    history = {'train_loss': [],
               'train_acc': [],
               'test_loss': [],
               'test_acc': []}
    # setup loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    # training loop
    print('Training Starts ')
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        val_loss = 0
        val_acc = 0
        
        for x, y in train_dataset:
            
            # x = x.to(device)
            y = y.to(device)
            outputs = model(x)  # (num_batch)
            
            cur_train_loss = criterion(outputs, y)
            cur_train_loss.backward()  # run back propagation
            optimizer.step()  # optimizer update all model parameters
            optimizer.zero_grad()  # set gradient to zero, avoid gradient accumulating
            # loss
            train_loss += cur_train_loss
            # acc
            _, pred_class = torch.max(outputs, 1)
            train_acc += (pred_class == y).sum().item() / batch_size

      # valid
        model.eval()  # start to train the model, activate training behavior
        with torch.no_grad():  # tell pytorch not to update parameters
            for images, labels in test_dataset:
                images = images.reshape(-1, 28 * 28).to(device)
                # images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                cur_valid_loss = criterion(outputs, labels)
                val_loss += cur_valid_loss
                _, pred_class = torch.max(outputs, 1)
                val_acc += (pred_class == labels).sum().item() / batch_size
        
        # print & record
        train_loss = train_loss / len(train_dataset)
        train_acc = train_acc / len(train_dataset)
        val_loss = val_loss / len(test_dataset)
        val_acc = val_acc / len(test_dataset)
        print(f"Epoch:{epoch + 1} / {epochs}, train loss:{train_loss:.5f}, train acc: {train_acc:.5f}, valid loss:{val_loss:.5f}, valid acc:{val_acc:.5f}")
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(val_loss)
        history['test_acc'].append(val_acc)

        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    
    return history

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

regularizer=0
dropout = 0
model = FeedForward(p=dropout,hidden_l1=500,hidden_l2=500)
hista = train_model(model, 
                    train_loader, 
                    test_loader, 
                    device, 
                    lr=0.0001, 
                    epochs=250, 
                    batch_size=128, 
                    weight_decay=regularizer)
# Out:
# Training Starts
# Epoch:1 / 250, train loss:0.67600, train acc: 0.84108, valid loss:0.29017, valid acc:0.90823
# Epoch:2 / 250, train loss:0.26816, train acc: 0.92246, valid loss:0.22524, valid acc:0.92316
# Validation loss decreased (inf --> 0.225237).  Saving model ...
# Epoch:3 / 250, train loss:0.21135, train acc: 0.93922, valid loss:0.18747, valid acc:0.93424
# Validation loss decreased (0.225237 --> 0.187466).  Saving model ...
# Epoch:4 / 250, train loss:0.17518, train acc: 0.94906, valid loss:0.15900, valid acc:0.94165
# Validation loss decreased (0.187466 --> 0.159004).  Saving model ...
# Epoch:5 / 250, train loss:0.14788, train acc: 0.95659, valid loss:0.14045, valid acc:0.94848
# Validation loss decreased (0.159004 --> 0.140446).  Saving model ...
# Epoch:6 / 250, train loss:0.12734, train acc: 0.96302, valid loss:0.12179, valid acc:0.95362
# Validation loss decreased (0.140446 --> 0.121788).  Saving model ...
# Epoch:7 / 250, train loss:0.11059, train acc: 0.96800, valid loss:0.11018, valid acc:0.95619
# Validation loss decreased (0.121788 --> 0.110183).  Saving model ...
# Epoch:8 / 250, train loss:0.09708, train acc: 0.97155, valid loss:0.10138, valid acc:0.95797
# Validation loss decreased (0.110183 --> 0.101379).  Saving model ...
# Epoch:9 / 250, train loss:0.08530, train acc: 0.97448, valid loss:0.09931, valid acc:0.95886
# Validation loss decreased (0.101379 --> 0.099307).  Saving model ...
# Epoch:10 / 250, train loss:0.07568, train acc: 0.97780, valid loss:0.09020, valid acc:0.96212
# Validation loss decreased (0.099307 --> 0.090200).  Saving model ...
# Epoch:11 / 250, train loss:0.06780, train acc: 0.98008, valid loss:0.08650, valid acc:0.96321
# Validation loss decreased (0.090200 --> 0.086499).  Saving model ...
# Epoch:12 / 250, train loss:0.05968, train acc: 0.98236, valid loss:0.07952, valid acc:0.96509
# Validation loss decreased (0.086499 --> 0.079518).  Saving model ...
# Epoch:13 / 250, train loss:0.05337, train acc: 0.98409, valid loss:0.07601, valid acc:0.96539
# Validation loss decreased (0.079518 --> 0.076014).  Saving model ...
# Epoch:14 / 250, train loss:0.04816, train acc: 0.98581, valid loss:0.07299, valid acc:0.96608
# Validation loss decreased (0.076014 --> 0.072991).  Saving model ...
# Epoch:15 / 250, train loss:0.04255, train acc: 0.98777, valid loss:0.07471, valid acc:0.96519
# EarlyStopping counter: 1 out of 5
# Epoch:16 / 250, train loss:0.03839, train acc: 0.98892, valid loss:0.06797, valid acc:0.96727
# Validation loss decreased (0.072991 --> 0.067966).  Saving model ...
# Epoch:17 / 250, train loss:0.03386, train acc: 0.99036, valid loss:0.06785, valid acc:0.96756
# Validation loss decreased (0.067966 --> 0.067851).  Saving model ...
# Epoch:18 / 250, train loss:0.03079, train acc: 0.99164, valid loss:0.06849, valid acc:0.96737
# EarlyStopping counter: 1 out of 5
# Epoch:19 / 250, train loss:0.02690, train acc: 0.99237, valid loss:0.06493, valid acc:0.96885
# Validation loss decreased (0.067851 --> 0.064928).  Saving model ...
# Epoch:20 / 250, train loss:0.02491, train acc: 0.99322, valid loss:0.06566, valid acc:0.96845
# EarlyStopping counter: 1 out of 5
# Epoch:21 / 250, train loss:0.02130, train acc: 0.99415, valid loss:0.06280, valid acc:0.96875
# Validation loss decreased (0.064928 --> 0.062800).  Saving model ...
# Epoch:22 / 250, train loss:0.01868, train acc: 0.99525, valid loss:0.06589, valid acc:0.96826
# EarlyStopping counter: 1 out of 5
# Epoch:23 / 250, train loss:0.01648, train acc: 0.99600, valid loss:0.06710, valid acc:0.96855
# EarlyStopping counter: 2 out of 5
# Epoch:24 / 250, train loss:0.01483, train acc: 0.99647, valid loss:0.06644, valid acc:0.96835
# EarlyStopping counter: 3 out of 5
# Epoch:25 / 250, train loss:0.01272, train acc: 0.99712, valid loss:0.06631, valid acc:0.96924
# EarlyStopping counter: 4 out of 5
# Epoch:26 / 250, train loss:0.01112, train acc: 0.99733, valid loss:0.06846, valid acc:0.96816
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
plt.plot(hista['train_acc'], label='Train')
plt.plot(hista['test_acc'], label='Valid')
plt.title("Classification Accuracy")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Classification Accuracy')
# <function matplotlib.pyplot.plot>

# %%
plt.plot(hista['train_loss'], label='Train')
plt.plot(hista['test_loss'], label='Valid')
plt.title("Cross entropy loss")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Cross entropy loss')
# <function matplotlib.pyplot.plot>

# %% [markdown]
# ### Three - layer feedforward network with regularizers

# %% [markdown]
# L2 reqularization

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

regularizer = 0.0001
model_with_reqularizer = FeedForward(p=dropout,hidden_l1=500,hidden_l2=500)
hist_l2_reqularizer = train_model(model_with_reqularizer, 
                    train_loader, 
                    test_loader, 
                    device, 
                    lr=0.0001, 
                    epochs=250, 
                    batch_size=128, 
                    weight_decay=regularizer)
# Out:
# Training Starts
# Epoch:1 / 250, train loss:0.67680, train acc: 0.84863, valid loss:0.29058, valid acc:0.90704
# Epoch:2 / 250, train loss:0.26639, train acc: 0.92372, valid loss:0.22564, valid acc:0.92573
# Validation loss decreased (inf --> 0.225637).  Saving model ...
# Epoch:3 / 250, train loss:0.21113, train acc: 0.93880, valid loss:0.18623, valid acc:0.93463
# Validation loss decreased (0.225637 --> 0.186232).  Saving model ...
# Epoch:4 / 250, train loss:0.17395, train acc: 0.94951, valid loss:0.16052, valid acc:0.94195
# Validation loss decreased (0.186232 --> 0.160522).  Saving model ...
# Epoch:5 / 250, train loss:0.14718, train acc: 0.95722, valid loss:0.13726, valid acc:0.94689
# Validation loss decreased (0.160522 --> 0.137259).  Saving model ...
# Epoch:6 / 250, train loss:0.12783, train acc: 0.96277, valid loss:0.12647, valid acc:0.94986
# Validation loss decreased (0.137259 --> 0.126472).  Saving model ...
# Epoch:7 / 250, train loss:0.11163, train acc: 0.96755, valid loss:0.11296, valid acc:0.95471
# Validation loss decreased (0.126472 --> 0.112957).  Saving model ...
# Epoch:8 / 250, train loss:0.09819, train acc: 0.97123, valid loss:0.10167, valid acc:0.95718
# Validation loss decreased (0.112957 --> 0.101670).  Saving model ...
# Epoch:9 / 250, train loss:0.08730, train acc: 0.97395, valid loss:0.09603, valid acc:0.95926
# Validation loss decreased (0.101670 --> 0.096030).  Saving model ...
# Epoch:10 / 250, train loss:0.07765, train acc: 0.97733, valid loss:0.08727, valid acc:0.96193
# Validation loss decreased (0.096030 --> 0.087271).  Saving model ...
# Epoch:11 / 250, train loss:0.07003, train acc: 0.97991, valid loss:0.08463, valid acc:0.96331
# Validation loss decreased (0.087271 --> 0.084633).  Saving model ...
# Epoch:12 / 250, train loss:0.06283, train acc: 0.98153, valid loss:0.08407, valid acc:0.96173
# Validation loss decreased (0.084633 --> 0.084073).  Saving model ...
# Epoch:13 / 250, train loss:0.05595, train acc: 0.98396, valid loss:0.07745, valid acc:0.96470
# Validation loss decreased (0.084073 --> 0.077449).  Saving model ...
# Epoch:14 / 250, train loss:0.05120, train acc: 0.98476, valid loss:0.07277, valid acc:0.96657
# Validation loss decreased (0.077449 --> 0.072774).  Saving model ...
# Epoch:15 / 250, train loss:0.04567, train acc: 0.98712, valid loss:0.06987, valid acc:0.96746
# Validation loss decreased (0.072774 --> 0.069868).  Saving model ...
# Epoch:16 / 250, train loss:0.04213, train acc: 0.98771, valid loss:0.07199, valid acc:0.96608
# EarlyStopping counter: 1 out of 5
# Epoch:17 / 250, train loss:0.03807, train acc: 0.98909, valid loss:0.07195, valid acc:0.96588
# EarlyStopping counter: 2 out of 5
# Epoch:18 / 250, train loss:0.03459, train acc: 0.99047, valid loss:0.06820, valid acc:0.96756
# Validation loss decreased (0.069868 --> 0.068196).  Saving model ...
# Epoch:19 / 250, train loss:0.03081, train acc: 0.99159, valid loss:0.06784, valid acc:0.96756
# Validation loss decreased (0.068196 --> 0.067840).  Saving model ...
# Epoch:20 / 250, train loss:0.02832, train acc: 0.99225, valid loss:0.06223, valid acc:0.96984
# Validation loss decreased (0.067840 --> 0.062228).  Saving model ...
# Epoch:21 / 250, train loss:0.02564, train acc: 0.99330, valid loss:0.06330, valid acc:0.97004
# EarlyStopping counter: 1 out of 5
# Epoch:22 / 250, train loss:0.02321, train acc: 0.99389, valid loss:0.06739, valid acc:0.96806
# EarlyStopping counter: 2 out of 5
# Epoch:23 / 250, train loss:0.02099, train acc: 0.99467, valid loss:0.06441, valid acc:0.96905
# EarlyStopping counter: 3 out of 5
# Epoch:24 / 250, train loss:0.01953, train acc: 0.99529, valid loss:0.06631, valid acc:0.96865
# EarlyStopping counter: 4 out of 5
# Epoch:25 / 250, train loss:0.01742, train acc: 0.99612, valid loss:0.06831, valid acc:0.96845
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
plt.plot(hist_l2_reqularizer['train_acc'], label='Train')
plt.plot(hist_l2_reqularizer['test_acc'], label='Valid')
plt.title("Classification Accuracy - L2 regularizer model")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Classification Accuracy')
# <function matplotlib.pyplot.plot>

# %%
plt.plot(hist_l2_reqularizer['train_loss'], label='Train')
plt.plot(hist_l2_reqularizer['test_loss'], label='Valid')
plt.title("Cross entropy loss - L2 regularizer model")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Cross entropy loss')
# <function matplotlib.pyplot.plot>

# %% [markdown]
# Dropout

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

dropout = 0.3
model_with_reqularizer = FeedForward(p=dropout,hidden_l1=500,hidden_l2=500)
hist_dropout_reqularizer = train_model(model_with_reqularizer, 
                    train_loader, 
                    test_loader, 
                    device, 
                    lr=0.0001, 
                    epochs=250, 
                    batch_size=128, 
                    weight_decay=regularizer)
# Out:
# Training Starts
# Epoch:1 / 250, train loss:0.74647, train acc: 0.80983, valid loss:0.31080, valid acc:0.90467
# Epoch:2 / 250, train loss:0.33497, train acc: 0.90037, valid loss:0.24413, valid acc:0.91901
# Validation loss decreased (inf --> 0.244134).  Saving model ...
# Epoch:3 / 250, train loss:0.27636, train acc: 0.91788, valid loss:0.20145, valid acc:0.93038
# Validation loss decreased (0.244134 --> 0.201453).  Saving model ...
# Epoch:4 / 250, train loss:0.23766, train acc: 0.92914, valid loss:0.17268, valid acc:0.93780
# Validation loss decreased (0.201453 --> 0.172676).  Saving model ...
# Epoch:5 / 250, train loss:0.20485, train acc: 0.93883, valid loss:0.14799, valid acc:0.94571
# Validation loss decreased (0.172676 --> 0.147994).  Saving model ...
# Epoch:6 / 250, train loss:0.18301, train acc: 0.94566, valid loss:0.13416, valid acc:0.94798
# Validation loss decreased (0.147994 --> 0.134160).  Saving model ...
# Epoch:7 / 250, train loss:0.16340, train acc: 0.95066, valid loss:0.11977, valid acc:0.95303
# Validation loss decreased (0.134160 --> 0.119771).  Saving model ...
# Epoch:8 / 250, train loss:0.14941, train acc: 0.95502, valid loss:0.11315, valid acc:0.95500
# Validation loss decreased (0.119771 --> 0.113145).  Saving model ...
# Epoch:9 / 250, train loss:0.13552, train acc: 0.95887, valid loss:0.10099, valid acc:0.95777
# Validation loss decreased (0.113145 --> 0.100993).  Saving model ...
# Epoch:10 / 250, train loss:0.12528, train acc: 0.96179, valid loss:0.09758, valid acc:0.95926
# Validation loss decreased (0.100993 --> 0.097577).  Saving model ...
# Epoch:11 / 250, train loss:0.11622, train acc: 0.96410, valid loss:0.09014, valid acc:0.95995
# Validation loss decreased (0.097577 --> 0.090135).  Saving model ...
# Epoch:12 / 250, train loss:0.10789, train acc: 0.96693, valid loss:0.08593, valid acc:0.96232
# Validation loss decreased (0.090135 --> 0.085929).  Saving model ...
# Epoch:13 / 250, train loss:0.10204, train acc: 0.96830, valid loss:0.08167, valid acc:0.96282
# Validation loss decreased (0.085929 --> 0.081669).  Saving model ...
# Epoch:14 / 250, train loss:0.09438, train acc: 0.97048, valid loss:0.08067, valid acc:0.96371
# Validation loss decreased (0.081669 --> 0.080666).  Saving model ...
# Epoch:15 / 250, train loss:0.08951, train acc: 0.97233, valid loss:0.07443, valid acc:0.96578
# Validation loss decreased (0.080666 --> 0.074426).  Saving model ...
# Epoch:16 / 250, train loss:0.08498, train acc: 0.97330, valid loss:0.06791, valid acc:0.96786
# Validation loss decreased (0.074426 --> 0.067914).  Saving model ...
# Epoch:17 / 250, train loss:0.08146, train acc: 0.97451, valid loss:0.06880, valid acc:0.96746
# EarlyStopping counter: 1 out of 5
# Epoch:18 / 250, train loss:0.07741, train acc: 0.97595, valid loss:0.06765, valid acc:0.96776
# Validation loss decreased (0.067914 --> 0.067649).  Saving model ...
# Epoch:19 / 250, train loss:0.07376, train acc: 0.97678, valid loss:0.06287, valid acc:0.96895
# Validation loss decreased (0.067649 --> 0.062873).  Saving model ...
# Epoch:20 / 250, train loss:0.06978, train acc: 0.97745, valid loss:0.06396, valid acc:0.96806
# EarlyStopping counter: 1 out of 5
# Epoch:21 / 250, train loss:0.06746, train acc: 0.97853, valid loss:0.05888, valid acc:0.97073
# Validation loss decreased (0.062873 --> 0.058878).  Saving model ...
# Epoch:22 / 250, train loss:0.06301, train acc: 0.98023, valid loss:0.05871, valid acc:0.97023
# Validation loss decreased (0.058878 --> 0.058707).  Saving model ...
# Epoch:23 / 250, train loss:0.06180, train acc: 0.98089, valid loss:0.05687, valid acc:0.97132
# Validation loss decreased (0.058707 --> 0.056871).  Saving model ...
# Epoch:24 / 250, train loss:0.06082, train acc: 0.98083, valid loss:0.05717, valid acc:0.97033
# EarlyStopping counter: 1 out of 5
# Epoch:25 / 250, train loss:0.05930, train acc: 0.98069, valid loss:0.05986, valid acc:0.96974
# EarlyStopping counter: 2 out of 5
# Epoch:26 / 250, train loss:0.05644, train acc: 0.98173, valid loss:0.05506, valid acc:0.97102
# Validation loss decreased (0.056871 --> 0.055056).  Saving model ...
# Epoch:27 / 250, train loss:0.05757, train acc: 0.98124, valid loss:0.06029, valid acc:0.96816
# EarlyStopping counter: 1 out of 5
# Epoch:28 / 250, train loss:0.05229, train acc: 0.98324, valid loss:0.05578, valid acc:0.97122
# EarlyStopping counter: 2 out of 5
# Epoch:29 / 250, train loss:0.05102, train acc: 0.98351, valid loss:0.05347, valid acc:0.97221
# Validation loss decreased (0.055056 --> 0.053470).  Saving model ...
# Epoch:30 / 250, train loss:0.05028, train acc: 0.98373, valid loss:0.05270, valid acc:0.97241
# Validation loss decreased (0.053470 --> 0.052697).  Saving model ...
# Epoch:31 / 250, train loss:0.04817, train acc: 0.98474, valid loss:0.05268, valid acc:0.97201
# Validation loss decreased (0.052697 --> 0.052684).  Saving model ...
# Epoch:32 / 250, train loss:0.04750, train acc: 0.98421, valid loss:0.05327, valid acc:0.97142
# EarlyStopping counter: 1 out of 5
# Epoch:33 / 250, train loss:0.04465, train acc: 0.98547, valid loss:0.05176, valid acc:0.97152
# Validation loss decreased (0.052684 --> 0.051759).  Saving model ...
# Epoch:34 / 250, train loss:0.04423, train acc: 0.98611, valid loss:0.05095, valid acc:0.97261
# Validation loss decreased (0.051759 --> 0.050945).  Saving model ...
# Epoch:35 / 250, train loss:0.04445, train acc: 0.98577, valid loss:0.05068, valid acc:0.97280
# Validation loss decreased (0.050945 --> 0.050678).  Saving model ...
# Epoch:36 / 250, train loss:0.04268, train acc: 0.98659, valid loss:0.04906, valid acc:0.97221
# Validation loss decreased (0.050678 --> 0.049063).  Saving model ...
# Epoch:37 / 250, train loss:0.04248, train acc: 0.98584, valid loss:0.04902, valid acc:0.97251
# Validation loss decreased (0.049063 --> 0.049024).  Saving model ...
# Epoch:38 / 250, train loss:0.03942, train acc: 0.98674, valid loss:0.05047, valid acc:0.97231
# EarlyStopping counter: 1 out of 5
# Epoch:39 / 250, train loss:0.03982, train acc: 0.98676, valid loss:0.04759, valid acc:0.97300
# Validation loss decreased (0.049024 --> 0.047591).  Saving model ...
# Epoch:40 / 250, train loss:0.03864, train acc: 0.98767, valid loss:0.04804, valid acc:0.97211
# EarlyStopping counter: 1 out of 5
# Epoch:41 / 250, train loss:0.03807, train acc: 0.98779, valid loss:0.04590, valid acc:0.97399
# Validation loss decreased (0.047591 --> 0.045901).  Saving model ...
# Epoch:42 / 250, train loss:0.03541, train acc: 0.98844, valid loss:0.05056, valid acc:0.97211
# EarlyStopping counter: 1 out of 5
# Epoch:43 / 250, train loss:0.03553, train acc: 0.98832, valid loss:0.04745, valid acc:0.97369
# EarlyStopping counter: 2 out of 5
# Epoch:44 / 250, train loss:0.03559, train acc: 0.98817, valid loss:0.04750, valid acc:0.97300
# EarlyStopping counter: 3 out of 5
# Epoch:45 / 250, train loss:0.03628, train acc: 0.98781, valid loss:0.04826, valid acc:0.97310
# EarlyStopping counter: 4 out of 5
# Epoch:46 / 250, train loss:0.03352, train acc: 0.98886, valid loss:0.04696, valid acc:0.97379
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
plt.plot(hist_dropout_reqularizer['train_acc'], label='Train')
plt.plot(hist_dropout_reqularizer['test_acc'], label='Valid')
plt.title("Classification Accuracy - Model with Dropout")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Classification Accuracy')
# <function matplotlib.pyplot.plot>

# %%
plt.plot(hist_dropout_reqularizer['train_loss'], label='Train')
plt.plot(hist_dropout_reqularizer['test_loss'], label='Valid')
plt.title("Cross entropy loss - Model with Dropout")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Cross entropy loss')
# <function matplotlib.pyplot.plot>

# %% [markdown]
# ### Comparisions

# %% [markdown]
# ### Comparision of models without regularizer and model with L2 regularizer

# %%
plt.plot(hista['test_acc'], 'r-', label='Feed forward network')
plt.plot(hist_l2_reqularizer['test_acc'], 'b-', label='Model with L2 regularizer')

plt.title('Comparing test accuracies')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test accuracies')
# Text(0.5, 0, 'Epochs')

# %%
plt.plot(hista['test_loss'], 'r-', label='Feed forward network')
plt.plot(hist_l2_reqularizer['test_loss'], 'b-', label='Model with L2 regularizer')

plt.title('Comparing test loss')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test loss')
# Text(0.5, 0, 'Epochs')

# %% [markdown]
# ### Comparision of models without regularizer and model with dropout

# %%
plt.plot(hista['test_acc'], 'r-', label='Feed forward network')
plt.plot(hist_dropout_reqularizer['test_acc'], 'm-', label='Model with Dropout')

plt.title('Comparing test accuracies')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test accuracies')
# Text(0.5, 0, 'Epochs')

# %%
plt.plot(hista['test_loss'], 'r-', label='Feed forward network')
plt.plot(hist_dropout_reqularizer['test_loss'], 'm-', label='Model with Dropout')

plt.title('Comparing test loss')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test loss')
# Text(0.5, 0, 'Epochs')

# %% [markdown]
# ### Comparision of models without regularizer, model with L2 regulizer and model with dropout

# %%
plt.plot(hista['test_acc'], 'r-', label='Feed forward network')
plt.plot(hist_l2_reqularizer['test_acc'], 'b-', label='Model with L2 regularizer')
plt.plot(hist_dropout_reqularizer['test_acc'], 'm-', label='Model with Dropout')

plt.title('Comparing test accuracies')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test accuracies')
# Text(0.5, 0, 'Epochs')

# %%
plt.plot(hista['test_loss'], 'r-', label='Feed forward network')
plt.plot(hist_l2_reqularizer['test_loss'], 'b-', label='Model with L2 regularizer')
plt.plot(hist_dropout_reqularizer['test_loss'], 'm-', label='Model with Dropout')

plt.title('Comparing test loss')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test loss')
# Text(0.5, 0, 'Epochs')

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Convolutional neural network

# %%
class SimpleConvnet(nn.Module):
    def __init__(self):
        super(SimpleConvnet, self).__init__()
        # conv net
        self.convnet = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3),  # (32, 26, 26)
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  #(32, 13, 13)  if stride is not provided, it will default to kernel_size

            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),  # (64, 11, 11),  param = (3*3*32+1)*64
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2),  # (64, 5, 5)
            
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3),  # (64, 3, 3)
            nn.Flatten() # 64*3*3 features after flattening 
        )
        # classifier
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(in_features=576, out_features=500),  # 576 = 64 * 3 * 3
            nn.ReLU(),
            nn.Linear(in_features=500, out_features=500),
            nn.ReLU(),
            nn.Linear(in_features=500, out_features=10)
        )
    def forward(self, x):
        x = self.convnet(x)
        x = self.classifier(x)

        return x

# %%
visual_model = SimpleConvnet()
summary(visual_model, (10, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SimpleConvnet                            --                        --
# ├─Sequential: 1-1                        [10, 576]                 --
# │    └─Conv2d: 2-1                       [10, 32, 26, 26]          320
# │    └─ReLU: 2-2                         [10, 32, 26, 26]          --
# │    └─MaxPool2d: 2-3                    [10, 32, 13, 13]          --
# │    └─Conv2d: 2-4                       [10, 64, 11, 11]          18,496
# │    └─ReLU: 2-5                         [10, 64, 11, 11]          --
# │    └─MaxPool2d: 2-6                    [10, 64, 5, 5]            --
# │    └─Conv2d: 2-7                       [10, 64, 3, 3]            36,928
# │    └─Flatten: 2-8                      [10, 576]                 --
# ├─Sequential: 1-2                        [10, 10]                  --
# │    └─Dropout: 2-9                      [10, 576]                 --
# │    └─Linear: 2-10                      [10, 500]                 288,500
# │    └─ReLU: 2-11                        [10, 500]                 --
# │    └─Linear: 2-12                      [10, 500]                 250,500
# │    └─ReLU: 2-13                        [10, 500]                 --
# │    └─Linear: 2-14                      [10, 10]                  5,010
# ==========================================================================================
# Total params: 599,754
# Trainable params: 599,754
# Non-trainable params: 0
# Total mult-adds (M): 33.31
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 2.48
# Params size (MB): 2.40
# Estimated Total Size (MB): 4.91
# ==========================================================================================

# %%
def train(model, train_dataset, test_dataset, device, 
                lr=0.0002, epochs=30, batch_size=256):
    
    # # construct dataloader
    # train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    # test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

    # move model to device
    model = model.to(device)
    early_stopping = EarlyStopping(patience=5, verbose=True)


    # history
    history = {'train_loss': [],
               'train_acc': [],
               'test_loss': [],
               'test_acc': []}

    # setup loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.RMSprop(model.parameters(), lr=lr)

    # training loop
    print('Training Start')
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        test_loss = 0
        test_acc = 0
        
        for x, y in train_loader:
            
            # move data to device
            x = x.to(device)
            y = y.to(device)
            
            # forward
            outputs = model(x)  # (num_batch, 45) 
            _, pred = torch.max(outputs, dim = -1)
            cur_train_loss = criterion(outputs, y)
            cur_train_acc = (pred == y).sum().item() / batch_size
            # backward
            cur_train_loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            # loss and acc
            train_loss += cur_train_loss
            train_acc += cur_train_acc

        # test start
        
        model.eval()
        with torch.no_grad():
            for x, y in test_loader:
                # move
                x = x.to(device)
                y = y.to(device)
                # predict
                outputs = model(x)
                _, pred = torch.max(outputs, dim = -1)
                cur_test_loss = criterion(outputs, y)
                cur_test_acc = (pred == y).sum().item() / batch_size 
                # loss and acc
                test_loss += cur_test_loss
                test_acc += cur_test_acc   

        # epoch output
        train_loss = (train_loss/len(train_loader)).item()
        train_acc = train_acc/len(train_loader)
        val_loss = (test_loss/len(test_loader)).item()
        val_acc = test_acc/len(test_loader)
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(val_loss)
        history['test_acc'].append(val_acc)
        print(f"Epoch:{epoch + 1} / {epochs}, train loss:{train_loss:.5f} train acc:{train_acc:.5f}, valid loss:{val_loss:.5f} valid acc:{val_acc:.5f}")

        early_stopping(val_loss, model)
        if early_stopping.early_stop:
            print("Early stopping")
            break
    
    return history

# %%
# define model
model = SimpleConvnet()

history = train(model, 
                train_dataset, 
                test_dataset, 
                device, 
                lr=0.0001, 
                epochs=250, 
                batch_size=128)
# Out:
# Training Start
# Epoch:1 / 250, train loss:0.48010 train acc:0.85245, valid loss:0.18877 valid acc:0.93078
# Epoch:2 / 250, train loss:0.18287 train acc:0.94283, valid loss:0.11906 valid acc:0.95164
# Validation loss decreased (inf --> 0.119056).  Saving model ...
# Epoch:3 / 250, train loss:0.12419 train acc:0.96089, valid loss:0.07010 valid acc:0.96657
# Validation loss decreased (0.119056 --> 0.070101).  Saving model ...
# Epoch:4 / 250, train loss:0.09832 train acc:0.96858, valid loss:0.05731 valid acc:0.97122
# Validation loss decreased (0.070101 --> 0.057314).  Saving model ...
# Epoch:5 / 250, train loss:0.08177 train acc:0.97408, valid loss:0.05753 valid acc:0.96984
# EarlyStopping counter: 1 out of 5
# Epoch:6 / 250, train loss:0.07091 train acc:0.97740, valid loss:0.04450 valid acc:0.97518
# Validation loss decreased (0.057314 --> 0.044502).  Saving model ...
# Epoch:7 / 250, train loss:0.06156 train acc:0.98016, valid loss:0.03855 valid acc:0.97646
# Validation loss decreased (0.044502 --> 0.038550).  Saving model ...
# Epoch:8 / 250, train loss:0.05611 train acc:0.98191, valid loss:0.03328 valid acc:0.97795
# Validation loss decreased (0.038550 --> 0.033275).  Saving model ...
# Epoch:9 / 250, train loss:0.05069 train acc:0.98336, valid loss:0.02986 valid acc:0.97933
# Validation loss decreased (0.033275 --> 0.029858).  Saving model ...
# Epoch:10 / 250, train loss:0.04618 train acc:0.98527, valid loss:0.03512 valid acc:0.97716
# EarlyStopping counter: 1 out of 5
# Epoch:11 / 250, train loss:0.04377 train acc:0.98619, valid loss:0.02938 valid acc:0.98002
# Validation loss decreased (0.029858 --> 0.029381).  Saving model ...
# Epoch:12 / 250, train loss:0.04111 train acc:0.98636, valid loss:0.02945 valid acc:0.97963
# EarlyStopping counter: 1 out of 5
# Epoch:13 / 250, train loss:0.03784 train acc:0.98757, valid loss:0.02689 valid acc:0.98111
# Validation loss decreased (0.029381 --> 0.026893).  Saving model ...
# Epoch:14 / 250, train loss:0.03586 train acc:0.98819, valid loss:0.02801 valid acc:0.97963
# EarlyStopping counter: 1 out of 5
# Epoch:15 / 250, train loss:0.03267 train acc:0.98902, valid loss:0.02367 valid acc:0.98131
# Validation loss decreased (0.026893 --> 0.023673).  Saving model ...
# Epoch:16 / 250, train loss:0.03113 train acc:0.98964, valid loss:0.02638 valid acc:0.98012
# EarlyStopping counter: 1 out of 5
# Epoch:17 / 250, train loss:0.03190 train acc:0.98911, valid loss:0.02762 valid acc:0.97963
# EarlyStopping counter: 2 out of 5
# Epoch:18 / 250, train loss:0.02863 train acc:0.99022, valid loss:0.02329 valid acc:0.98121
# Validation loss decreased (0.023673 --> 0.023294).  Saving model ...
# Epoch:19 / 250, train loss:0.02748 train acc:0.99065, valid loss:0.02396 valid acc:0.98131
# EarlyStopping counter: 1 out of 5
# Epoch:20 / 250, train loss:0.02627 train acc:0.99102, valid loss:0.02636 valid acc:0.98170
# EarlyStopping counter: 2 out of 5
# Epoch:21 / 250, train loss:0.02536 train acc:0.99180, valid loss:0.02003 valid acc:0.98309
# Validation loss decreased (0.023294 --> 0.020025).  Saving model ...
# Epoch:22 / 250, train loss:0.02380 train acc:0.99179, valid loss:0.02109 valid acc:0.98269
# EarlyStopping counter: 1 out of 5
# Epoch:23 / 250, train loss:0.02221 train acc:0.99220, valid loss:0.02165 valid acc:0.98210
# EarlyStopping counter: 2 out of 5
# Epoch:24 / 250, train loss:0.02207 train acc:0.99202, valid loss:0.02154 valid acc:0.98250
# EarlyStopping counter: 3 out of 5
# Epoch:25 / 250, train loss:0.02148 train acc:0.99272, valid loss:0.02105 valid acc:0.98170
# EarlyStopping counter: 4 out of 5
# Epoch:26 / 250, train loss:0.01921 train acc:0.99319, valid loss:0.01945 valid acc:0.98230
# Validation loss decreased (0.020025 --> 0.019451).  Saving model ...
# Epoch:27 / 250, train loss:0.01882 train acc:0.99355, valid loss:0.02109 valid acc:0.98161
# EarlyStopping counter: 1 out of 5
# Epoch:28 / 250, train loss:0.01921 train acc:0.99294, valid loss:0.01836 valid acc:0.98329
# Validation loss decreased (0.019451 --> 0.018357).  Saving model ...
# Epoch:29 / 250, train loss:0.01795 train acc:0.99329, valid loss:0.01892 valid acc:0.98269
# EarlyStopping counter: 1 out of 5
# Epoch:30 / 250, train loss:0.01760 train acc:0.99349, valid loss:0.01773 valid acc:0.98319
# Validation loss decreased (0.018357 --> 0.017727).  Saving model ...
# Epoch:31 / 250, train loss:0.01695 train acc:0.99392, valid loss:0.01829 valid acc:0.98220
# EarlyStopping counter: 1 out of 5
# Epoch:32 / 250, train loss:0.01635 train acc:0.99410, valid loss:0.02158 valid acc:0.98170
# EarlyStopping counter: 2 out of 5
# Epoch:33 / 250, train loss:0.01551 train acc:0.99417, valid loss:0.02016 valid acc:0.98190
# EarlyStopping counter: 3 out of 5
# Epoch:34 / 250, train loss:0.01457 train acc:0.99452, valid loss:0.01984 valid acc:0.98309
# EarlyStopping counter: 4 out of 5
# Epoch:35 / 250, train loss:0.01440 train acc:0.99477, valid loss:0.01880 valid acc:0.98289
# EarlyStopping counter: 5 out of 5
# Early stopping

# %%
plt.plot(history['train_acc'], label='Train')
plt.plot(history['test_acc'], label='Valid')
plt.title("Classification Accuracy - CNN")
plt.xlabel('Epochs')
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Classification Accuracy - CNN')
# Text(0.5, 0, 'Epochs')
# <function matplotlib.pyplot.plot>

# %%
plt.plot(history['train_loss'], label='Train')
plt.plot(history['test_loss'], label='Valid')
plt.title("Cross-entropy loss - CNN")
plt.legend()
plt.plot
# Out:
# Text(0.5, 1.0, 'Cross-entropy loss - CNN')
# <function matplotlib.pyplot.plot>

# %% [markdown]
# ### Comparision of models without regularizer, model with L2 regularizer, model with dropout and CNN

# %%
plt.plot(hista['test_acc'], 'r-', label='Model')
plt.plot(hist_l2_reqularizer['test_acc'], 'b-', label='Model with L2 regularizer')
plt.plot(hist_dropout_reqularizer['test_acc'], 'm-', label='Model with Dropout')
plt.plot(history['test_acc'], 'g-', label='Model with convolutional layers')

plt.title('Comparing test accuracies')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test accuracies')
# Text(0.5, 0, 'Epochs')

# %%
plt.plot(hista['test_loss'], 'r-', label='Model')
plt.plot(hist_l2_reqularizer['test_loss'], 'b-', label='Model with L2 regularizer')
plt.plot(hist_dropout_reqularizer['test_loss'], 'm-', label='Model with Dropout')
plt.plot(history['test_loss'], 'g-', label='Model with convolutional layers')


plt.title('Comparing test loss')
plt.xlabel('Epochs')
plt.legend()

plt.show()
# Out:
# Text(0.5, 1.0, 'Comparing test loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')
