# %% [markdown]
# ### Question 2 : Part 2

# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals, print_function, division
import string
import random
from data_utils import *
from rnn import *
import torch
import codecs
from tqdm import tqdm
import string
from math import log

#Set GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running using {device}")
# Out:
# Running using cuda

# %% [markdown]
# #Load vocabulary files

# %%
input_lang = torch.load('data-bin/fra.data')
output_lang = torch.load('data-bin/eng.data')

# %%
#Create and empty RNN model
encoder = EncoderRNN(input_size=input_lang.n_words, device=device)
attn_decoder = AttnDecoderRNN(output_size=output_lang.n_words, device=device)
#Load the saved model weights into the RNN model
encoder.load_state_dict(torch.load('model/encoder'))
attn_decoder.load_state_dict(torch.load('model/decoder'))
# Out:
# <All keys matched successfully>

# %%
#Return the decoder output given input sentence 
#Additionally, the previous predicted word and previous decoder state can also be given as input
def translate_single_word(encoder, decoder, sentence, decoder_input=None, decoder_hidden=None, max_length=MAX_LENGTH, device=device):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence, device)
        input_length = input_tensor.size()[0]
        
        encoder = encoder.to(device)
        decoder = decoder.to(device)
        
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        if decoder_input==None:
            decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS
        else:
            decoder_input = torch.tensor([[output_lang.word2index[decoder_input]]], device=device) 
        
        if decoder_hidden == None:        
            decoder_hidden = encoder_hidden
        
        decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
        return decoder_output.data, decoder_hidden

# %%
def beam_search_decoder(data, k):
	sequences = [[list(), 0.0]]
	# walk over each step in sequence
	for row in data:
		all_candidates = list()
		# expand each current candidate
		for i in range(len(sequences)):
			seq, score = sequences[i]
			for j in range(len(row)):
				candidate = [seq + [j], score - log(row[j])]
				all_candidates.append(candidate)
		# order all candidates by score
		ordered = sorted(all_candidates, key=lambda tup:tup[1])
		# select k best
		sequences = ordered[:k]
	return sequences

# %%
def beam_search(encoder,decoder,input_sentence,beam_size=1,max_length=MAX_LENGTH):
    decoded_output = []
    
    #Predicted the first word
    decoder_output, decoder_hidden = translate_single_word(encoder, decoder, input_sentence, decoder_input=None, decoder_hidden=None)
    
    #Get the probability of all output words
    decoder_output_probs = decoder_output.data
    idxs = beam_search_decoder(decoder_output_probs, beam_size) #get argMax for top three
    
	
    #Convert the predicted id to the word
    # first_word = output_lang.index2word[idx.item()]
    selected_first_words = [output_lang.index2word[idx[0]] for (idx, score) in idxs]
    
    #Add the predicted word to the output list and also set it as the previous prediction
    decoded_output.extend([[x] for x in selected_first_words]) # [[],[],[]]
    previous_decoded_output = selected_first_words # should be of length beam_size
    # print(f"selected words{selected_first_words}, and decoded_output {decoded_output}, previous_decoded_output {previous_decoded_output}")
    assert beam_size == len(selected_first_words)
    
    #Loop until the maximum length
    
    
    for i in range(max_length):
        beams = []
        for j, previous_decode in enumerate(previous_decoded_output):
            decoder_output, decoder_hidden = translate_single_word(encoder, decoder, input_sentence, previous_decode, decoder_hidden)
            decoder_output_probs = decoder_output.data
            beams.extend(decoder_output_probs)
        
        idxs = beam_search_decoder(beams, beam_size) 
        
        for idx in idxs:
            selected_word = output_lang.index2word[idx[0][0]]
            if selected_word == "EOS":
                break
            else:
                decoded_output[j].extend(selected_word)
                previous_decoded_output[j] = selected_word
                
    output_translation = " ".join(i for i in decoded_output[2])
    
    return output_translation

# %%
target_sentences = ["i can speak a bit of french .",
        "i ve bought some cheese and milk .",
        "boy where is your older brother ?",
        "i ve just started reading this book .",
        "she loves writing poems ."]

source_sentences = ["je parle un peu francais .",
            "j ai achete du fromage et du lait .",
            "garcon ou est ton grand frere ?",
            "je viens justement de commencer ce livre .",
            "elle adore ecrire des poemes ."]


def lines_from_file(file_name):
    lines = []
    with open(file_name) as f:
        lines = f.readlines()
    return lines
        

target = codecs.open('test_beam_1.out','w',encoding='utf-8')

beam_size = 3
for i,source_sentence in enumerate(source_sentences):

    target_sentence = normalizeString(target_sentences[i])
    input_sentence = normalizeString(source_sentence)
    
    hypothesis = beam_search(encoder, attn_decoder, input_sentence, beam_size=beam_size)
    print("S-"+str(i)+": "+input_sentence)
    print("T-"+str(i)+": "+target_sentence)
    print("H-"+str(i)+": "+hypothesis)
    print()
    target.write(hypothesis+'\n')
target.close()
# Out:
# S-0: je parle un peu francais .
# T-0: i can speak a bit of french .
# H-0: you m m m a a f r e n c h . .
#
# S-1: j ai achete du fromage et du lait .
# T-1: i ve bought some cheese and milk .
# H-1: we m a m m . . . . . . .
#
# S-2: garcon ou est ton grand frere ?
# T-2: boy where is your older brother ?
# H-2: i s i s s t o o ? b r o t h e r ? ? ? ? ? ? ? ? ? ? ?
#
# S-3: je viens justement de commencer ce livre .
# T-3: i ve just started reading this book .
# H-3: you m m a m t o t o t h e . . . . . . . . .
#
# S-4: elle adore ecrire des poemes .
# T-4: she loves writing poems .
# H-4: they i s i s i s f r o m s o f . . . . . .

# %% [markdown]
# ### Question 2: Part 3

# %%
# ! pip install sacrebleu

# %%
from sacrebleu.metrics import BLEU
k_list = list(range(3,24))
belu_scores = []
def lines_from_file(file_name):
    lines = []
    with open(file_name) as f:
        lines = f.readlines()
    return lines
        
    
source_sentences = lines_from_file("data/valid.fra")
target_sentences = lines_from_file("data/test.eng")

for k in k_list:
    print("running for k ",k)
    beam_size = k
    hyps = []
    beam_size = k
    for i,source_sentence in enumerate(source_sentences):

        target_sentence = normalizeString(target_sentences[i])
        input_sentence = normalizeString(source_sentence)

        hypothesis = beam_search(encoder, attn_decoder, input_sentence, beam_size=beam_size)
        # print(hypothesis)
    hyps.append(hypothesis) 

    bleu = BLEU()
    result = bleu.corpus_score(hyps, source_sentences)
    print(result.score)
    belu_scores.append(result.score)
# Out:
# running for k  3
# 3.377156414337854
# running for k  4

# %%
# from the plot best value for k is obtained
best_k = 4

# %%
from matplotlib import pyplot as plt
plt.plot(k_list, belu_scores) 
plt.show()

# %% [markdown]
# ### Question 2 : Part 4

# %%
def lines_from_file(file_name):
    lines = []
    with open(file_name) as f:
        lines = f.readlines()
    return lines
        
    
source_sentences = lines_from_file("data/test.fra")
target_sentences = lines_from_file("data/test.eng")

beam_size = best_k

for i,source_sentence in enumerate(source_sentences):

    target_sentence = normalizeString(target_sentences[i])
    input_sentence = normalizeString(source_sentence)

    hypothesis = beam_search(encoder, attn_decoder, input_sentence, beam_size=beam_size)
    print("S-"+str(i)+": "+input_sentence)
    print("T-"+str(i)+": "+target_sentence)
    print("H-"+str(i)+": "+hypothesis)
    print()
# Out:
# S-0: je t aime !
# T-0: i love you !
# H-0: he
#
# S-1: fais tout ce qu il te dit .
# T-1: do whatever he tells you .
# H-1: i
#
# S-2: c est difficile d avoir des idees geniales .
# T-2: it s difficult to have great ideas .
# H-2: she
#
# S-3: je me suis etendu sur l herbe .
# T-3: i laid myself on the grass .
# H-3: he
#
# S-4: je vais acheter une nouvelle voiture .
# T-4: i am going to buy a new car .
# H-4: you
#
# S-5: je suis tres sensible a la chaleur .
# T-5: i am very sensitive to heat .
# H-5: they
#
# S-6: mes parents m adorent .
# T-6: i m loved by my parents .
# H-6: they
#
# S-7: j etais en mission a l etranger .
# T-7: i was abroad on an assignment .
# H-7: we
#
# S-8: je m interesse a la natation .
# T-8: i am interested in swimming .
# H-8: he
#
# S-9: j ai un ordinateur .
# T-9: i have a computer .
# H-9: he
#
# S-10: je veux jouer de la guitare .
# T-10: i want to play the guitar .
# H-10: we
#
# S-11: en ce qui me concerne je suis satisfait .
# T-11: as for me i am satisfied .
# H-11: you
#
# S-12: dois je ouvrir la fenetre ?
# T-12: do i have to open the window ?
# H-12: we
#
# S-13: vas tu faire tes devoirs cet apres midi ?
# T-13: are you going to do your homework this afternoon ?
# H-13: i
#
# S-14: il est a la hauteur de la tache .
# T-14: he is equal to the task .
# H-14: she
#
# S-15: vers quelle heure ?
# T-15: about what time ?
# H-15: you
#
# S-16: comme le ciel est bleu !
# T-16: how blue the sky is !
# H-16: i
#
# S-17: on parle l anglais dans de nombreux pays .
# T-17: english is spoken in many countries .
# H-17: you
#
# S-18: je te suis reconnaissant pour ta gentillesse .
# T-18: i am grateful to you for your kindness .
# H-18: we
#
# S-19: viens ici john .
# T-19: come here john .
# H-19: we
#
# S-20: etes vous membre de cette societe ?
# T-20: are you a member of this society ?
# H-20: you
#
# S-21: de quelle longueur est ce pont ?
# T-21: how long is the bridge ?
# H-21: she
#
# S-22: c etait exactement son intention .
# T-22: that was exactly what she intended .
# H-22: i
#
# S-23: le diner est pret .
# T-23: dinner is ready .
# H-23: we
#
# S-24: j ai envie de partir en voyage .
# T-24: i feel like going on a trip .
# H-24: you
#
# S-25: est ce que tony etudie apres le diner ?
# T-25: does tony study after dinner ?
# H-25: she
#
# S-26: chaque famille a un squelette dans son placard .
# T-26: every family has a skeleton in the closet .
# H-26: you
#
# S-27: maman et papa sont tres nerveux .
# T-27: mom and dad are very nervous .
# H-27: you
#
# S-28: c est un ami tres proche .
# T-28: he is my close friend .
# H-28: i
#
# S-29: je l ai vu traverser la route .
# T-29: i saw him cross the street .
# H-29: we
#
# S-30: j etudie .
# T-30: i study .
# H-30: m
#
# S-31: attends une minute s il te plait .
# T-31: hold on a minute please .
# H-31: he
#
# S-32: personne ne sait son nom .
# T-32: no one knows his name .
# H-32: you
#
# S-33: le savoir est une force .
# T-33: knowledge is power .
# H-33: she
#
# S-34: sors de ma vie !
# T-34: get out of my life !
# H-34: she
#
# S-35: je viens de tokyo japon .
# T-35: i m from tokyo japan .
# H-35: you
#
# S-36: dites moi ce qu il est devenu .
# T-36: tell me what has become of him .
# H-36: she
#
# S-37: peux tu le rencontrer ?
# T-37: can you meet him ?
# H-37: we
#
# S-38: il est revenu deux heures plus tard .
# T-38: he came back after two hours .
# H-38: they
#
# S-39: il boit trop de biere .
# T-39: he drinks too much beer .
# H-39: we
#
# S-40: il gagne sa vie comme garcon d hotel .
# T-40: he earns his living as a hotel boy .
# H-40: i
#
# S-41: il vit dans une grande maison .
# T-41: he lives in a big house .
# H-41: we
#
# S-42: il m a appris a ecrire un poeme .
# T-42: he taught me how to write a poem .
# H-42: she
#
# S-43: il est entre dans ma chambre .
# T-43: he entered my room .
# H-43: she
#
# S-44: il peut courir plus vite que moi .
# T-44: he can run faster than i .
# H-44: i
#
# S-45: il leva les yeux vers le ciel .
# T-45: he looked up at the sky .
# H-45: i
#
# S-46: il est borne .
# T-46: he s closed minded .
# H-46: she
#
# S-47: il va a paris en avion demain .
# T-47: he is flying to paris tomorrow .
# H-47: they
#
# S-48: je l ai vue jouer du piano .
# T-48: i saw her play the piano .
# H-48: he
#
# S-49: elle a beaucoup de vetements .
# T-49: she has quite a lot of clothes .
# H-49: he
#
# S-50: elle n est pas pauvre .
# T-50: she isn t poor .
# H-50: we
#
# S-51: elle a de petits pieds .
# T-51: she has small feet .
# H-51: he
#
# S-52: debout !
# T-52: stand up !
# H-52: you
#
# S-53: soyez respectueux envers les personnes agees .
# T-53: be respectful to the elderly .
# H-53: i
#
# S-54: je deteste les reptiles .
# T-54: i can t stand reptiles .
# H-54: he
#
# S-55: je me couche a heures .
# T-55: i go to bed at eleven .
# H-55: he
#
# S-56: c est le chef de classe .
# T-56: he is at the head of the class .
# H-56: they
#
# S-57: ca doit etre dur pour toi .
# T-57: it must be hard for you .
# H-57: he
#
# S-58: ils ont leurs propres problemes .
# T-58: they have their own troubles .
# H-58: he
#
# S-59: ne le prends pas pour toi .
# T-59: don t take it personally .
# H-59: he
#
# S-60: il dit toujours la meme chose .
# T-60: he always says the same thing .
# H-60: i
#
# S-61: cela va disparaitre naturellement dans deux semaines .
# T-61: it will go away by itself in two weeks .
# H-61: they
#
# S-62: elle a une conception cynique de la vie .
# T-62: she is very cynical about life .
# H-62: is
#
# S-63: la voila !
# T-63: there she is !
# H-63: she
#
# S-64: elle souffre d une maladie grave .
# T-64: she s suffering from a serious disease .
# H-64: he
#
# S-65: elle est venue !
# T-65: she came !
# H-65: he
#
# S-66: le toit de ma maison est rouge .
# T-66: the roof of my house is red .
# H-66: he
#
# S-67: arrivera t il a attraper le train ?
# T-67: will he be able to catch the train ?
# H-67: i
#
# S-68: je ne sais pas ce que c est .
# T-68: i don t know what it is .
# H-68: you
#
# S-69: qu est ce que tu as fait hier ?
# T-69: what did you do yesterday ?
# H-69: she
#
# S-70: je suis droitier .
# T-70: i am right handed .
# H-70: they
#
# S-71: c est de loin la meilleure maniere .
# T-71: this is by far the best way .
# H-71: i
#
# S-72: elle ne viendra surement pas a temps .
# T-72: it is doubtful whether she will come on time .
# H-72: he
#
# S-73: la nourriture en italie etait bonne .
# T-73: the food was great in italy .
# H-73: she
#
# S-74: a qui sont ces livres ?
# T-74: whose books are these ?
# H-74: she
#
# S-75: je viens de la rencontrer sur la rue .
# T-75: i just met her on the street .
# H-75: she
#
# S-76: quelle jupe aimes tu ?
# T-76: which skirt do you like ?
# H-76: i
#
# S-77: commence a lire ou tu t es arrete .
# T-77: start reading where you left off .
# H-77: they
#
# S-78: il achete seulement ce qui lui sera utile .
# T-78: he buys only what ll be useful for him .
# H-78: we
#
# S-79: j aime etudier l histoire .
# T-79: i love studying history .
# H-79: we
#
# S-80: calme toi mon gars .
# T-80: would you relax man ?
# H-80: he
#
# S-81: il partira aussi .
# T-81: he will go as well .
# H-81: i
#
# S-82: ne lui en dis rien .
# T-82: don t tell her about it .
# H-82: you
#
# S-83: je lui dis constamment de bien se comporter .
# T-83: i m constantly telling her to behave herself .
# H-83: you
#
# S-84: j ai deja ecrit une lettre .
# T-84: i have already written a letter .
# H-84: he
#
# S-85: cette actrice est toujours aussi belle .
# T-85: that actress is as beautiful as ever .
# H-85: they
#
# S-86: je suis convaincu de son innocence .
# T-86: i am convinced of his innocence .
# H-86: you
#
# S-87: je suis le plus jeune enfant .
# T-87: i m the youngest child .
# H-87: you
#
# S-88: il fait un peu froid .
# T-88: it is a little cold .
# H-88: we
#
# S-89: je suis vraiment desole .
# T-89: i m very sorry .
# H-89: m
#
# S-90: vous devez vous lever un peu plus tot .
# T-90: you must get up a little earlier .
# H-90: re
#
# S-91: pourquoi veux tu etudier a l etranger ?
# T-91: why do you want to study abroad ?
# H-91: i
#
# S-92: pourquoi es tu venue ici ?
# T-92: what have you come here for ?
# H-92: we
#
# S-93: je veux savoir si vous serez libres demain .
# T-93: i want to know if you ll be free tomorrow .
# H-93: we
#
# S-94: comment va ton boulot ?
# T-94: how s your job ?
# H-94: we
#
# S-95: le monde entier desire la paix .
# T-95: all the world desires peace .
# H-95: we
#
# S-96: il est bete a manger du foin .
# T-96: he s as dumb as a rock .
# H-96: s
#
# S-97: vous conduisez comme un tare !
# T-97: you re driving like a maniac !
# H-97: re
#
# S-98: je compte jusqu a dix .
# T-98: i count to ten .
# H-98: he
#
# S-99: j ai fini le travail hier .
# T-99: i finished the job yesterday .
# H-99: we
#
# S-100: les enfants veulent toujours devenir adultes .
# T-100: children always want to become adults .
# H-100: i
#
# S-101: je suis japonais mais tu es americain .
# T-101: i am japanese but you are an american .
# H-101: he
#
# S-102: n importe quel enfant peut repondre a ca .
# T-102: any child can answer that .
# H-102: you
#
# S-103: tu as deux livres .
# T-103: you have two pounds .
# H-103: i
#
# S-104: je n aime pas trop le cafe .
# T-104: i don t care much for coffee .
# H-104: he
#
# S-105: ca fait une paille .
# T-105: long time no see .
# H-105: he
#
# S-106: je pense que ce fait est tres important .
# T-106: i think that fact is very important .
# H-106: she
#
# S-107: ma cuillere est trop grande !
# T-107: my spoon is too big !
# H-107: i
#
# S-108: quiconque d entre vous peut le faire .
# T-108: any of you can do it .
# H-108: you
#
# S-109: ton chien est il mechant ?
# T-109: is your dog mean ?
# H-109: she
#
# S-110: chaque personne a paye mille dollars .
# T-110: each individual paid dollars .
# H-110: he
#
# S-111: tu ne dois pas enfreindre les regles .
# T-111: you are not allowed to violate the rules .
# H-111: they
#
# S-112: j espere que tu t amuses bien .
# T-112: i hope you re having fun .
# H-112: m
#
# S-113: nous avons ete surpris par son comportement .
# T-113: we were surprised by his behavior .
# H-113: i
#
# S-114: elle prend souvent son petit dejeuner la .
# T-114: she often eats breakfast there .
# H-114: he
#
# S-115: elle est mal elevee .
# T-115: she is bad mannered .
# H-115: he
#
# S-116: il faut que je te rappelle ta promesse .
# T-116: i must remind you of your promise .
# H-116: i
#
# S-117: je m en branle .
# T-117: i don t give a fuck .
# H-117: they
#
# S-118: il gagne du temps .
# T-118: he s stalling for time .
# H-118: they
#
# S-119: il aura ans en fevrier .
# T-119: he ll be seventeen in february .
# H-119: you
#
# S-120: il y a un probleme ?
# T-120: is there a problem ?
# H-120: she
#
# S-121: il avait des cheveux gris .
# T-121: he had gray hair .
# H-121: she
#
# S-122: on a gagne le match .
# T-122: we won the match .
# H-122: they
#
# S-123: vous devez vous reposer un peu .
# T-123: you have to rest a little .
# H-123: he
#
# S-124: je ne peux plus le faire .
# T-124: i can t do it anymore .
# H-124: he
#
# S-125: en australie on parle l anglais .
# T-125: in australia english is spoken .
# H-125: i
#
# S-126: j ai vraiment besoin d un verre maintenant .
# T-126: i really need a drink now .
# H-126: we
#
# S-127: mere nature est genereuse .
# T-127: mother nature is generous .
# H-127: they
#
# S-128: voulez vous coucher avec moi ce soir ?
# T-128: do you want to have sex with me tonight ?
# H-128: she
#
# S-129: fumer tue .
# T-129: smoking kills .
# H-129: he
#
# S-130: vous avez l air splendide sur ces photos .
# T-130: you look great in these photos .
# H-130: they
#
# S-131: quelle belle ville !
# T-131: what a beautiful town !
# H-131: she
#
# S-132: tom parle deux langues etrangeres .
# T-132: tom speaks two foreign languages .
# H-132: they
#
# S-133: le chocolat suisse fond reellement dans ta bouche .
# T-133: swiss chocolate really melts in your mouth .
# H-133: we
#
# S-134: veuillez parler plus fort .
# T-134: please say it more loudly .
# H-134: i
#
# S-135: il a des problemes .
# T-135: he is in trouble .
# H-135: they
#
# S-136: l anglais est ma langue maternelle .
# T-136: english is my native language .
# H-136: he
#
# S-137: quel age pourrait bien avoir son grand pere ?
# T-137: how old might his grandfather be ?
# H-137: you
#
# S-138: ton plan semble excellent .
# T-138: your plan seems excellent .
# H-138: he
#
# S-139: ou est la sortie ?
# T-139: where is the exit ?
# H-139: she
#
# S-140: nous avons etudie tout l apres midi .
# T-140: we were studying all afternoon .
# H-140: you
#
# S-141: il est dentiste de profession .
# T-141: he is a dentist by profession .
# H-141: i
#
# S-142: comment ecrit on ton nom de famille ?
# T-142: how is your last name written ?
# H-142: she
#
# S-143: si tu as besoin d aide demande moi .
# T-143: if you need any help ask me .
# H-143: they
#
# S-144: ces pommes sont grosses .
# T-144: those apples are big .
# H-144: you
#
# S-145: peut etre as tu raison apres tout .
# T-145: maybe you re right after all .
# H-145: he
#
# S-146: c est egalement vrai .
# T-146: that s true too .
# H-146: you
#
# S-147: c est une victoire facile .
# T-147: it s an easy victory .
# H-147: you
#
# S-148: je dois remplacer la pile de la radio .
# T-148: i have to replace the radio s battery .
# H-148: he
#
# S-149: il reste rarement chez lui le dimanche .
# T-149: he seldom stays home on sundays .
# H-149: she
#
# S-150: regarde t il la television chaque jour ?
# T-150: does he watch television every day ?
# H-150: i
#
# S-151: je ne suis pas tout a fait sur .
# T-151: i m not quite sure .
# H-151: they
#
# S-152: prends les medicaments .
# T-152: take the medicine .
# H-152: i
#
# S-153: pourquoi me fais tu ca ?
# T-153: why are you doing this to me ?
# H-153: you
#
# S-154: ma s ur est une tres bonne dactylo .
# T-154: my sister is a very good typist .
# H-154: you
#
# S-155: je ne connais aucune des deux filles .
# T-155: i don t know either girl .
# H-155: you
#
# S-156: c est quoi un dossier ouvert ?
# T-156: what is an open folder ?
# H-156: you
#
# S-157: aimes tu etre seul ?
# T-157: do you like to be alone ?
# H-157: she
#
# S-158: vous etes un drole d oiseau .
# T-158: you re a funny guy .
# H-158: i
#
# S-159: en es tu sure ?
# T-159: are you sure about this ?
# H-159: he
#
# S-160: tu es tres belle .
# T-160: you look beautiful .
# H-160: they
#
# S-161: il vaut mieux le laisser se reposer .
# T-161: best to let him rest .
# H-161: i
#
# S-162: laissez le moi .
# T-162: leave this to me .
# H-162: you
#
# S-163: je n arrive pas a te comprendre .
# T-163: i can t understand you .
# H-163: m
#
# S-164: j aime observer la campagne .
# T-164: i like watching the countryside .
# H-164: she
#
# S-165: vos papiers !
# T-165: show me your papers !
# H-165: we
#
# S-166: j ai quelquefois besoin de mon pere .
# T-166: sometimes i need my father .
# H-166: that
#
# S-167: de rien !
# T-167: you re welcome !
# H-167: they
#
# S-168: les enfants sont deja partis a l ecole .
# T-168: the children already went to school .
# H-168: she
#
# S-169: ce chien est gros .
# T-169: that dog is big .
# H-169: you
#
# S-170: je suis gene .
# T-170: i m uncomfortable .
# H-170: he
#
# S-171: je suis capable de parler .
# T-171: i m able to speak .
# H-171: they
#
# S-172: je sais comment le faire .
# T-172: i know how to do it .
# H-172: you
#
# S-173: elle a dit qu elle avait ete heureuse .
# T-173: she said she had been happy .
# H-173: i
#
# S-174: c est du tout cuit .
# T-174: it s a piece of cake .
# H-174: she
#
# S-175: je suis trop occupe pour te parler maintenant .
# T-175: i m too busy to talk to you now .
# H-175: we
#
# S-176: il etait un poete et un ecrivain .
# T-176: he was a poet and writer .
# H-176: i
#
# S-177: ceci est plus joli .
# T-177: this one is prettier .
# H-177: you
#
# S-178: je serai heureuse de travailler avec toi .
# T-178: i ll be happy to work with you .
# H-178: she
#
# S-179: cette theorie est vraie pour le japon .
# T-179: this theory is true of japan .
# H-179: i
#
# S-180: j habite ici depuis longtemps .
# T-180: i have lived here for a long time .
# H-180: m
#
# S-181: je suis desolee mon pere est sorti .
# T-181: i m sorry my father is out .
# H-181: you
#
# S-182: tom a achete a mary un parapluie cher .
# T-182: tom bought mary an expensive umbrella .
# H-182: she
#
# S-183: j ai egalement pris du bon temps .
# T-183: i had a good time too .
# H-183: you
#
# S-184: nous avons garde les enfants tranquilles .
# T-184: we kept the children quiet .
# H-184: they
#
# S-185: ne lui parlons pas .
# T-185: let s not talk to her .
# H-185: he
#
# S-186: on apprend de ses erreurs .
# T-186: we learn by trial and error .
# H-186: i
#
# S-187: nous serons ensemble pour toujours .
# T-187: we will be together forever .
# H-187: they
#
# S-188: nous petit dejeunons .
# T-188: we are having breakfast .
# H-188: you
#
# S-189: es tu folle ?
# T-189: are you crazy ?
# H-189: he
#
# S-190: nous vivons pres de la frontiere .
# T-190: we live near the border .
# H-190: he
#
# S-191: j ai pris a droite .
# T-191: i turned right .
# H-191: she
#
# S-192: comment ?
# T-192: come again ?
# H-192: re
#
# S-193: il chante bien .
# T-193: he is good at singing .
# H-193: you
#
# S-194: je sais que c est mal .
# T-194: i know it s wrong .
# H-194: you
#
# S-195: j ai peur d avoir peur .
# T-195: i m afraid of being afraid .
# H-195: he
#
# S-196: cette chambre est a louer .
# T-196: this room is for rent .
# H-196: she
#
# S-197: veuillez emmener les autres .
# T-197: please bring the others .
# H-197: they
#
# S-198: je ne suis pas plus jeune que toi .
# T-198: i am no younger than you are .
# H-198: he
#
# S-199: ou joue tony ?
# T-199: where is tony playing ?
# H-199: we
#
# S-200: ce qu il dit n etait pas vrai .
# T-200: what he said was not true .
# H-200: they
#
# S-201: etes vous prete pour le voyage ?
# T-201: are you ready for the trip ?
# H-201: you
#
# S-202: t a t il montre le tableau ?
# T-202: did he show you the picture ?
# H-202: she
#
# S-203: veux tu quoi que ce soit a manger ?
# T-203: do you want anything to eat ?
# H-203: i
#
# S-204: je recois souvent des lettres d elle .
# T-204: i often receive letters from her .
# H-204: he
#
# S-205: soyez prudente quant a ce que vous mangez .
# T-205: be careful about what you eat .
# H-205: they
#
# S-206: elle lui a demande s il etait heureux .
# T-206: she asked him if he was happy .
# H-206: you
#
# S-207: je n arrive pas a comprendre ses sentiments .
# T-207: i can t understand his feelings .
# H-207: you
#
# S-208: ca te dirait de cuisiner avec moi ?
# T-208: how s about cooking something up with me ?
# H-208: we
#
# S-209: j aime nager .
# T-209: i like to swim .
# H-209: we
#
# S-210: quel est ton numero ?
# T-210: what is your number ?
# H-210: i
#
# S-211: c est un japonais typique .
# T-211: he s a typical japanese man .
# H-211: s
#
# S-212: ne me faites pas rire !
# T-212: don t make me laugh !
# H-212: he
#
# S-213: je sais qu elle ignore qui je suis .
# T-213: i know that she doesn t know who i am .
# H-213: m
#
# S-214: je n ai rien entendu .
# T-214: i ve heard nothing .
# H-214: they
#
# S-215: il leche le cul de son patron .
# T-215: he arse licks his boss .
# H-215: she
#
# S-216: il n est pas mon genre .
# T-216: he s not my type .
# H-216: she
#
# S-217: change la phrase s il te plait .
# T-217: please change the sentence .
# H-217: we
#
# S-218: le roi a enleve ses vetements .
# T-218: the king took his clothes off .
# H-218: she
#
# S-219: j ai besoin de quelque chose pour enfant .
# T-219: i need something for a child .
# H-219: we
#
# S-220: arrete d ergoter .
# T-220: don t split hairs .
# H-220: you
#
# S-221: je sais ou elle vit .
# T-221: i know where she lives .
# H-221: she
#
# S-222: je pense que c est un bon enseignant .
# T-222: i think that he s a good teacher .
# H-222: you
#
# S-223: tu as davantage d energie que moi .
# T-223: you have more energy than i .
# H-223: they
#
# S-224: si vous le dites .
# T-224: if you say so .
# H-224: they
#
# S-225: je ne sais pas comment l expliquer .
# T-225: i don t know how to explain it .
# H-225: they
#
# S-226: elle aurait echoue sans son aide .
# T-226: she would have failed without his help .
# H-226: we
#
# S-227: vous devez continuer a vous exercer .
# T-227: you must continue to train .
# H-227: they
#
# S-228: je n ai pas d ennemis .
# T-228: i don t have enemies .
# H-228: they
#
# S-229: a quoi te prepares tu ?
# T-229: what are you up to ?
# H-229: i
#
# S-230: ce qu il dit est en fait vrai .
# T-230: what he s saying is actually true .
# H-230: you
#
# S-231: avez vous capte ce qu il a dit ?
# T-231: did you catch what he said ?
# H-231: we
#
# S-232: c est une jolie robe que vous portez .
# T-232: that s a pretty dress you have on .
# H-232: he
#
# S-233: il n a pas peur .
# T-233: he has no fear .
# H-233: i
#
# S-234: vous serez toujours bienvenus .
# T-234: you will always be welcome .
# H-234: he
#
# S-235: apparemment la glace est tres dangereuse !
# T-235: apparently ice is lethal !
# H-235: she
#
# S-236: c est l amour le vrai .
# T-236: this is true love .
# H-236: you
#
# S-237: c etait juste une question de temps .
# T-237: it was just a matter of time .
# H-237: she
#
# S-238: il y a la quelque chose .
# T-238: there s something in here .
# H-238: you
#
# S-239: elle est ouverte d esprit .
# T-239: she s open minded .
# H-239: we
#
# S-240: l eau est pure .
# T-240: the water is pure .
# H-240: she
#
# S-241: traite la avec respect .
# T-241: treat her with respect .
# H-241: i
#
# S-242: c est une nouvelle de grande importance .
# T-242: the news is of great importance .
# H-242: i
#
# S-243: elles n y arrivent pas .
# T-243: they can t do that .
# H-243: i
#
# S-244: comment le fait elle ?
# T-244: how does she do it ?
# H-244: he
#
# S-245: il le fait correctement .
# T-245: he s doing it right .
# H-245: we
#
# S-246: j ai quelque chose pour toi .
# T-246: i ve got something for you .
# H-246: we
#
# S-247: tu auras un nouveau frere .
# T-247: you will have a new brother .
# H-247: i
#
# S-248: c est le boulot de mes reves .
# T-248: this is my dream job .
# H-248: they
#
# S-249: je veux dire au revoir .
# T-249: i want to say goodbye .
# H-249: they
#
# S-250: nous avons besoin de regles !
# T-250: we need rules !
# H-250: they
#
# S-251: je suis assis sur une chaise tres petite .
# T-251: i m sitting on a very small chair .
# H-251: he
#
# S-252: je ne porte pas de boxer .
# T-252: i am not wearing any underwear .
# H-252: she
#
# S-253: mary est la cousine de tom .
# T-253: mary is tom s cousin .
# H-253: he
#
# S-254: elles viennent de la meme ville .
# T-254: they come from the same town .
# H-254: we
#
# S-255: elle se promene en sous vetements .
# T-255: she s walking around in panties and bra .
# H-255: i
#
# S-256: que je suis heureuse aujourd hui !
# T-256: how happy i am today !
# H-256: you
#
# S-257: j attends avec impatience de vous revoir .
# T-257: i m looking forward to seeing you again .
# H-257: forward
#
# S-258: il y a une maniere .
# T-258: there is one way .
# H-258: i
#
# S-259: peut il le faire ?
# T-259: can he do it ?
# H-259: we
#
# S-260: es tu devenu completement fou ?
# T-260: have you gone completely mad ?
# H-260: he
#
# S-261: veux tu un journal ou un magazine ?
# T-261: would you like a newspaper or magazine ?
# H-261: i
#
# S-262: quiconque est il blesse ?
# T-262: is anybody hurt ?
# H-262: we
#
# S-263: t interesses tu a moi ?
# T-263: are you interested in me ?
# H-263: aren
#
# S-264: a qui est ce sac a main ?
# T-264: whose handbag is this ?
# H-264: i
#
# S-265: je me deteste .
# T-265: i hate myself .
# H-265: you
#
# S-266: elle n est pas sure d etre prete .
# T-266: she s not sure she s ready .
# H-266: i
#
# S-267: elle est la pour te proteger .
# T-267: she s here to protect you .
# H-267: you
#
# S-268: je sais ou trouver de l eau .
# T-268: i know where to find water .
# H-268: you
#
# S-269: il a supplie qu on epargne sa vie .
# T-269: he begged for his life .
# H-269: we
#
# S-270: si j oublie merci de me le rappeler .
# T-270: if i forget please remind me .
# H-270: they
#
# S-271: ce n etait pas moi .
# T-271: it wasn t me .
# H-271: he
#
# S-272: une crise dure a peu pres cinq minutes .
# T-272: a bout lasts about five minutes .
# H-272: he
#
# S-273: ce dictionnaire est a moi .
# T-273: that dictionary is mine .
# H-273: they
#
# S-274: veuillez ne pas toucher .
# T-274: please do not touch .
# H-274: you
#
# S-275: ne touche pas je te prie .
# T-275: please do not touch .
# H-275: she
#
# S-276: m aime t il ?
# T-276: does he like me ?
# H-276: they
#
# S-277: j ai un horaire charge .
# T-277: i have a tight schedule .
# H-277: you
#
# S-278: je pense que vous etes barree .
# T-278: i think you re nuts .
# H-278: m
#
# S-279: je ne vous ai jamais vue ainsi .
# T-279: i ve never seen you like this .
# H-279: we
#
# S-280: personne ne va te faire de mal .
# T-280: nobody s going to hurt you .
# H-280: we
#
# S-281: saisis ceci !
# T-281: grab hold of this .
# H-281: you
#
# S-282: laisse moi attraper mon portefeuille !
# T-282: let me get my wallet .
# H-282: you
#
# S-283: ne soyez pas contrariees !
# T-283: don t be upset .
# H-283: he
#
# S-284: ne sois pas fou !
# T-284: don t be crazy .
# H-284: we
#
# S-285: veux tu t arreter ?
# T-285: do you want to stop ?
# H-285: you
#
# S-286: sors d ici !
# T-286: get out of here !
# H-286: we
#
# S-287: je suis desole de t avoir hurle dessus .
# T-287: i m sorry i yelled at you .
# H-287: he
#
# S-288: je ne les bats pas .
# T-288: i don t beat them .
# H-288: they
#
# S-289: ca ne vieillit jamais .
# T-289: it never gets old .
# H-289: she
#
# S-290: sois calme !
# T-290: be still .
# H-290: you
#
# S-291: le connaissiez vous bien ?
# T-291: did you know him well ?
# H-291: you
#
# S-292: qu as tu a perdre ?
# T-292: what do you have to lose ?
# H-292: we
#
# S-293: arrete de parler je te prie !
# T-293: please stop talking .
# H-293: i
#
# S-294: je serai toujours la pour vous .
# T-294: i ll always be here for you .
# H-294: we
#
# S-295: j ai dine avec un ami hier soir .
# T-295: i had dinner with a friend last night .
# H-295: m
#
# S-296: je ne veux pas etre ton ami .
# T-296: i don t want to be your friend .
# H-296: he
#
# S-297: sens ca !
# T-297: feel this .
# H-297: we
#
# S-298: c est un pauvre type sans c ur .
# T-298: he s a cold hearted jerk .
# H-298: i
#
# S-299: vous etes givre !
# T-299: you re nuts !
# H-299: i
#
# S-300: c est un rouspeteur .
# T-300: he s a grouch .
# H-300: i
#
# S-301: l avez vous entendu ?
# T-301: did you hear it ?
# H-301: you
#
# S-302: qu est ce qui vous a effrayee ?
# T-302: what scared you ?
# H-302: i
#
# S-303: j adore tes yeux .
# T-303: i love your eyes .
# H-303: we
#
# S-304: je veux noter tout ca .
# T-304: i want to write all of this down .
# H-304: they
#
# S-305: vous savez quelle chanson je veux chanter .
# T-305: you know what song i want to sing .
# H-305: they
#
# S-306: soyez prudente je vous prie .
# T-306: please be careful .
# H-306: we
#
# S-307: je ne peux pas repondre a ca .
# T-307: i can t answer that .
# H-307: we
#
# S-308: je veux vous parler de cette liste .
# T-308: i want to talk to you about this list .
# H-308: we
#
# S-309: je pense que ca marche .
# T-309: i think it works .
# H-309: we
#
# S-310: tiens toi la ou tu es !
# T-310: stand where you are !
# H-310: i
#
# S-311: ai je manque quelque chose ?
# T-311: did i miss something ?
# H-311: he
#
# S-312: ne me force pas a te tuer !
# T-312: don t make me kill you .
# H-312: we
#
# S-313: nous ne pouvons pas etre plus precis .
# T-313: we can t be more specific .
# H-313: they
#
# S-314: tu auras besoin d argent .
# T-314: you ll need some money .
# H-314: he
#
# S-315: n aie pas l air si suspicieuse !
# T-315: don t look so suspicious .
# H-315: he
#
# S-316: que portes tu ?
# T-316: what are you wearing ?
# H-316: you
#
# S-317: marie n avait pas soif .
# T-317: marie wasn t thirsty .
# H-317: you
#
# S-318: elles ont raison .
# T-318: they re right .
# H-318: re
#
# S-319: quiconque est il la dedans ?
# T-319: is there anyone in here ?
# H-319: i
#
# S-320: personne ne se trouve dans la piece .
# T-320: no one is in the room .
# H-320: i
#
# S-321: pourquoi voulez vous perdre du poids en realite ?
# T-321: why do you really want to lose weight ?
# H-321: i
#
# S-322: faites attention a vous !
# T-322: watch yourselves .
# H-322: he
#
# S-323: nous sommes jumeaux .
# T-323: we re twins .
# H-323: re
#
# S-324: on ne peut plus le nier .
# T-324: you can t deny that anymore .
# H-324: you
#
# S-325: elle chapeaute serieusement .
# T-325: she s as mad as a hatter .
# H-325: we
#
# S-326: c est tout ce que j ai vu .
# T-326: that s all i saw .
# H-326: they
#
# S-327: j ai trouve ceci sous ton lit .
# T-327: i found this under your bed .
# H-327: you
#
# S-328: les deux hommes etaient partenaires en affaires .
# T-328: the two men were business partners .
# H-328: we
#
# S-329: tous les deux etaient nus .
# T-329: both were naked .
# H-329: you
#
# S-330: tu as assez de temps .
# T-330: you have enough time .
# H-330: we
#
# S-331: il ne sort jamais la nuit tombee .
# T-331: he never goes out after dark .
# H-331: they
#
# S-332: je pense beaucoup a lui .
# T-332: i think about him a lot .
# H-332: she
#
# S-333: elles ne mangent pas de viande .
# T-333: they don t eat meat .
# H-333: i
#
# S-334: dites moi ou elle se trouve !
# T-334: tell me where she is .
# H-334: she
#
# S-335: quand tu as raison tu as raison .
# T-335: when you re right you re right .
# H-335: s
#
# S-336: j aime vraiment ce garcon .
# T-336: i really like that guy .
# H-336: we
#
# S-337: elle m a saoule la nuit derniere .
# T-337: she got me drunk last night .
# H-337: he
#
# S-338: il n est pas parfait .
# T-338: he s not perfect .
# H-338: i
#
# S-339: qui est en train de regarder ?
# T-339: who s watching ?
# H-339: tired
#
# S-340: vous avez probablement raison .
# T-340: you re probably right .
# H-340: re
#
# S-341: etes vous surprises ?
# T-341: are you surprised ?
# H-341: aren
#
# S-342: pourquoi ne vous laissez vous pas aller ?
# T-342: why don t you loosen up ?
# H-342: i
#
# S-343: pourquoi ne vas tu pas discuter avec lui ?
# T-343: why don t you go talk to him ?
# H-343: he
#
# S-344: il etait trop abasourdi pour parler .
# T-344: he was too stunned to talk .
# H-344: i
#
# S-345: dites moi ce qui s est vraiment passe !
# T-345: tell me what really happened .
# H-345: you
#
# S-346: il est sur le point de partir .
# T-346: he s about to go .
# H-346: you
#
# S-347: tu gaspilles des munitions .
# T-347: you re wasting ammo .
# H-347: re
#
# S-348: c est toi la maitresse .
# T-348: you re the master .
# H-348: i
#
# S-349: il est alle trop loin .
# T-349: he has gone too far .
# H-349: i
#
# S-350: je ne lui dis pas tout .
# T-350: i didn t tell her everything .
# H-350: you
#
# S-351: je n ai pas le temps pour ca .
# T-351: i don t have the time for this .
# H-351: you
#
# S-352: prenez ce que vous voulez !
# T-352: take what you want .
# H-352: i
#
# S-353: il n ecoute pas .
# T-353: he doesn t listen .
# H-353: we
#
# S-354: je ne vois pas de quelle maniere .
# T-354: i don t see how .
# H-354: you
#
# S-355: ne restez pas dehors toute la nuit !
# T-355: don t stay out all night .
# H-355: they
#
# S-356: ils sont jaloux de nous .
# T-356: they are jealous of us .
# H-356: he
#
# S-357: elle est tres timide .
# T-357: she s very shy .
# H-357: he
#
# S-358: vous n etes pas aussi jeunes que tom .
# T-358: you re not as young as tom .
# H-358: he
#
# S-359: j ignore ce qui te soucie tant .
# T-359: i don t know what you re so worried about .
# H-359: we
#
# S-360: j ignore s ils y vivent encore .
# T-360: i don t know if they still live there .
# H-360: you
#
# S-361: je ne sais pas vraiment quoi dire .
# T-361: i don t quite know what to say .
# H-361: m
#
# S-362: tout le monde est reste calme .
# T-362: everyone stayed calm .
# H-362: he
#
# S-363: tout le monde est reste debout .
# T-363: everyone stayed standing .
# H-363: he
#
# S-364: il m a demande mon numero de telephone .
# T-364: he asked me for my phone number .
# H-364: we
#
# S-365: je suis tres impatient de le faire .
# T-365: i just can t wait to do that .
# H-365: you
#
# S-366: je connais ta camarade de chambre .
# T-366: i know your roommate .
# H-366: they
#
# S-367: je n ai rien promis de tel .
# T-367: i promised no such thing .
# H-367: she
#
# S-368: il me faut vraiment y aller .
# T-368: i really need to go .
# H-368: you
#
# S-369: ca semble etrange n est ce pas ?
# T-369: it feels weird doesn t it ?
# H-369: i
#
# S-370: ne sois pas si idiot !
# T-370: don t be such a fool .
# H-370: he
#
# S-371: il vous faut prendre soin de vous .
# T-371: you ve got to take care of yourself .
# H-371: i
#
# S-372: je pense que nous sommes presque pretes .
# T-372: i think we re about ready .
# H-372: they
#
# S-373: je n y pense meme plus .
# T-373: i don t even think about it anymore .
# H-373: we
#
# S-374: j ai determine quand nous sommes supposees arriver .
# T-374: i found out when we re supposed to arrive .
# H-374: you
#
# S-375: j ai fait moi meme pousser ces carottes .
# T-375: i grew these carrots myself .
# H-375: we
#
# S-376: je veux le faire pour vous .
# T-376: i want to do it for you .
# H-376: we
#
# S-377: je veux tout simplement faire mon travail .
# T-377: i just want to get my work done .
# H-377: you
#
# S-378: je pense que nous pouvons nous en occuper .
# T-378: i think we can handle it .
# H-378: we
#
# S-379: je sais exactement ou je veux me rendre .
# T-379: i know exactly where i want to go .
# H-379: they
#
# S-380: c est une belle femme .
# T-380: she s a beautiful woman .
# H-380: s
#
# S-381: je veux me fier a toi .
# T-381: i want to trust you .
# H-381: m
#
# S-382: je veux que tu sois en securite .
# T-382: i want you to be safe .
# H-382: they
#
# S-383: tom n aime pas beaucoup le poker .
# T-383: tom doesn t like poker very much .
# H-383: she
#
# S-384: j ignore de qui vous parlez .
# T-384: i don t know who you re talking about .
# H-384: we
#
# S-385: je ne veux pas vraiment y aller seul .
# T-385: i don t really want to go there by myself .
# H-385: he
#
# S-386: je requiers des conseils .
# T-386: i require advice .
# H-386: we
#
# S-387: j ai dit de ne pas le faire .
# T-387: i said don t do that .
# H-387: you
#
# S-388: je ne vois pas ce qui a change .
# T-388: i don t see what s changed .
# H-388: he
#
# S-389: je ne veux vivre ici .
# T-389: i don t want to live here .
# H-389: he
#
# S-390: je me rejouis que vous compreniez .
# T-390: i m glad that you understand .
# H-390: m
#
# S-391: elle peut partir demain .
# T-391: she can leave tomorrow .
# H-391: they
#
# S-392: ne m achete plus de cadeaux !
# T-392: don t buy me presents anymore .
# H-392: he
#
# S-393: je songe a demissionner .
# T-393: i m considering resigning .
# H-393: she
#
# S-394: je rassemble des informations .
# T-394: i m gathering information .
# H-394: you
#
# S-395: marie est une femme .
# T-395: mary is a woman .
# H-395: she
#
# S-396: tom boit un peu cafe .
# T-396: tom is drinking some coffee .
# H-396: she
#
# S-397: je peux t apprendre a nager .
# T-397: i can teach you how to swim .
# H-397: she
#
# S-398: j ai besoin de minutes .
# T-398: i need minutes .
# H-398: you
#
# S-399: tom est deux fois plus vieux que marie .
# T-399: tom is twice mary s age .
# H-399: i
#
# S-400: nous sommes ici pour rencontrer tom .
# T-400: we re here to meet tom .
# H-400: i
#
# S-401: tom est arrive un peu tot .
# T-401: tom was a little early .
# H-401: you
#
# S-402: ils etaient tous coupables .
# T-402: they were all guilty .
# H-402: i
#
# S-403: il est tres enrhume .
# T-403: he is suffering from a bad cold in the nose .
# H-403: she
#
# S-404: peut etre tom sait il quelque chose .
# T-404: maybe tom knows something .
# H-404: you
#
# S-405: avez vous un cours pour debutants ?
# T-405: do you have a course for beginners ?
# H-405: you
#
# S-406: ils nous prennent pour des jambons .
# T-406: they re taking us for fools .
# H-406: he
#
# S-407: je suis completement embrouillee .
# T-407: i m totally confused .
# H-407: he
#
# S-408: elles ont encore perdu .
# T-408: they lost again .
# H-408: we
#
# S-409: tom est maintenant en danger .
# T-409: tom is now in danger .
# H-409: we
#
# S-410: tu es une personne merveilleuse .
# T-410: you re a wonderful guy .
# H-410: they
#
# S-411: il me faut perdre un peu de poids .
# T-411: i need to lose some weight .
# H-411: we
#
# S-412: vous etes parfait a tout .
# T-412: you re perfect at everything .
# H-412: he
#
# S-413: j en suis familier .
# T-413: i m accustomed to this .
# H-413: you
#
# S-414: lis le moi !
# T-414: read it to me .
# H-414: you
#
# S-415: ce batiment est ancien .
# T-415: this building is ancient .
# H-415: i
#
# S-416: on sert le petit dejeuner a huit heures .
# T-416: breakfast is served at eight o clock .
# H-416: he
#
# S-417: on n achete rien de cher .
# T-417: we buy nothing expensive .
# H-417: you
#
# S-418: ca ne va plus du tout .
# T-418: things aren t going well at all any more .
# H-418: i
#
# S-419: les enfants ont froid .
# T-419: the children are cold .
# H-419: you
#
# S-420: elle vient de secher le cours de francais .
# T-420: she s just skipped french class .
# H-420: s
#
# S-421: elle est malade depuis la semaine derniere .
# T-421: she has been sick since last week .
# H-421: s
#
# S-422: il fait tres chaud aujourd hui .
# T-422: it s very warm today .
# H-422: we
#
# S-423: va me chercher du vin .
# T-423: go and get me some wine .
# H-423: she
#
# S-424: elle n est pas parfaite .
# T-424: she s not perfect .
# H-424: i
#
# S-425: ai je tant change ?
# T-425: have i changed that much ?
# H-425: he
#
# S-426: est ce que tu me dis la verite ?
# T-426: are you telling me the truth ?
# H-426: she
#
# S-427: on aurait du se lever plus tot .
# T-427: we should ve gotten up earlier .
# H-427: he
#
# S-428: tentons le !
# T-428: let s just try it .
# H-428: she
#
# S-429: j attends encore .
# T-429: i m still waiting .
# H-429: you
#
# S-430: ne regarde pas la bas .
# T-430: don t look there .
# H-430: she
#
# S-431: ma petite copine est chinoise .
# T-431: my girlfriend is chinese .
# H-431: she
#
# S-432: sont ils tous tes amis ?
# T-432: are all of them your friends ?
# H-432: they
#
# S-433: venez vous joindre a nous !
# T-433: come join us .
# H-433: i
#
# S-434: les riches sont differents de vous et moi .
# T-434: the rich are different from you and me .
# H-434: and
#
# S-435: l aimes tu ?
# T-435: do you love him ?
# H-435: i
#
# S-436: c est tres facile .
# T-436: this is very easy .
# H-436: you
#
# S-437: quand me l avez vous dit ?
# T-437: when did you tell me that ?
# H-437: he
#
# S-438: mon pere m a enseigne a le faire .
# T-438: my dad taught me how to do it .
# H-438: he
#
# S-439: la nature est cruelle .
# T-439: nature is cruel .
# H-439: they
#
# S-440: tom vient de diner .
# T-440: tom has just finished eating dinner .
# H-440: i
#
# S-441: je veux que vous et moi soyons heureux .
# T-441: i want you and me to be happy .
# H-441: he
#
# S-442: comment pouvez vous savoir qui je suis ?
# T-442: how do you know who i am ?
# H-442: he
#
# S-443: la fille la bas est ma s ur .
# T-443: that girl over there is my sister .
# H-443: he
#
# S-444: je dois encore essayer .
# T-444: i still have to try .
# H-444: m
#
# S-445: alors pourquoi etes vous ici ?
# T-445: so why are you here ?
# H-445: we
#
# S-446: il l apprecie .
# T-446: he likes her .
# H-446: you
#
# S-447: je n ai pas tres envie de discuter .
# T-447: i don t feel much like talking .
# H-447: you
#
# S-448: j ignore ce qui aurait pu arriver .
# T-448: i don t know what could ve happened .
# H-448: you
#
# S-449: on peut se fier a lui .
# T-449: you can rely on him .
# H-449: i
#
# S-450: tu m as suivie n est ce pas ?
# T-450: you ve been following me haven t you ?
# H-450: re
#
# S-451: cela fait il mal ou que ce soit ?
# T-451: does it hurt anywhere ?
# H-451: we
#
# S-452: laisse moi le faire a ta place !
# T-452: let me do this for you .
# H-452: we
#
# S-453: qu est une phrase ?
# T-453: what s a sentence ?
# H-453: i
#
# S-454: es tu en train de boire ?
# T-454: are you drinking ?
# H-454: he
#
# S-455: qu es tu en train de boire ?
# T-455: what re you drinking ?
# H-455: she
#
# S-456: personne n est chez lui .
# T-456: no one s home .
# H-456: she
#
# S-457: il n y a pas de nourriture .
# T-457: there s no food .
# H-457: they
#
# S-458: d ou viennent ils ?
# T-458: where do they come from ?
# H-458: she
#
# S-459: bien je ferai de mon mieux .
# T-459: good i will do my best .
# H-459: he
#
# S-460: l eau est merveilleuse .
# T-460: water is amazing .
# H-460: she
#
# S-461: il est parti pour londres debut juillet .
# T-461: he left for london in the beginning of july .
# H-461: they
#
# S-462: il etait en colere apres sa fille .
# T-462: he was angry with his daughter .
# H-462: she
#
# S-463: ils s en sont bien occupe .
# T-463: they handled it well .
# H-463: we
#
# S-464: comment peux tu etre aussi dur ?
# T-464: how can you be so callous ?
# H-464: she
#
# S-465: peut etre pouvons nous nous asseoir ensemble .
# T-465: maybe we can sit together .
# H-465: you
#
# S-466: elle mange quelque chose .
# T-466: she s eating something .
# H-466: he
#
# S-467: elle se parle a elle toute seule .
# T-467: she is muttering to herself .
# H-467: he
#
# S-468: tu es trop bon pour elle .
# T-468: you re too good for her .
# H-468: she
#
# S-469: elle est toujours tres polie .
# T-469: she s always very polite .
# H-469: we
#
# S-470: je suis ne avec douze doigts .
# T-470: i was born with twelve fingers .
# H-470: we
#
# S-471: vais je reussir ?
# T-471: will i make it through ?
# H-471: she
#
# S-472: je sais ce que je veux .
# T-472: i know what i want .
# H-472: m
#
# S-473: n est ce pas suffisant pour vous ?
# T-473: isn t that enough for you ?
# H-473: i
#
# S-474: es tu sur d y etre pret ?
# T-474: are you sure you re up for it ?
# H-474: you
#
# S-475: tom connait bien les problemes d argent .
# T-475: tom is no stranger to money problems .
# H-475: you
#
# S-476: je ne te supervise pas .
# T-476: i m not supervising you .
# H-476: m
#
# S-477: nous avons tous ete choques par les nouvelles .
# T-477: all of us were shocked by the news .
# H-477: they
#
# S-478: pensez vous que je puisse l executer ?
# T-478: do you think i can pull this off ?
# H-478: you
#
# S-479: tom est desormais tres fache contre moi .
# T-479: tom is now very angry with me .
# H-479: they
#
# S-480: ce type est un artiste !
# T-480: this fellow is an artist !
# H-480: i
#
# S-481: vous avez probablement raison .
# T-481: you have a point .
# H-481: re
#
# S-482: pouvons nous commencer la partie ?
# T-482: can we get started with the game ?
# H-482: he
#
# S-483: je n apprecie pas l humour de tom .
# T-483: i don t appreciate tom s humor .
# H-483: tom
#
# S-484: laisse entrer un peu d air frais .
# T-484: let some fresh air in .
# H-484: you
#
# S-485: quelle meilleure veine un type peut il avoir ?
# T-485: how lucky can one guy be ?
# H-485: you
#
# S-486: le mieux est de laisser couler l eau .
# T-486: the best way is to take things as they come .
# H-486: we
#
# S-487: tout n est pas une question d argent .
# T-487: not everything s about money .
# H-487: she
#
# S-488: je ne demande pas d argent .
# T-488: i m not asking for money .
# H-488: you
#
# S-489: je vous ai presque tire dessus .
# T-489: i almost shot you .
# H-489: she
#
# S-490: tom fera la vaisselle .
# T-490: tom will wash dishes .
# H-490: she
#
# S-491: je me sens perdu sans toi .
# T-491: i feel lost without you .
# H-491: he
#
# S-492: je serai en train de travailler .
# T-492: i ll be working .
# H-492: we
#
# S-493: c est un vol direct tokyo londres .
# T-493: it s a direct flight from tokyo to london .
# H-493: you
#
# S-494: que pensez vous de cette tenue ?
# T-494: what do you think about this outfit ?
# H-494: i
#
# S-495: pouvons nous reparer ca ?
# T-495: can we fix this ?
# H-495: we
#
# S-496: nous avons fini .
# T-496: we re finished .
# H-496: they
#
# S-497: ce n etait pas notre faute .
# T-497: this was not our fault .
# H-497: i
#
# S-498: je vais fermer la porte maintenant .
# T-498: i m going to close the door now .
# H-498: we
#
# S-499: maintenant laissez nous .
# T-499: now leave us .
# H-499: he
#
# S-500: je suis desole d etre habille comme ca .
# T-500: i m sorry that i m dressed like this .
# H-500: she
#
# S-501: le grec est une langue difficile .
# T-501: greek is a difficult language .
# H-501: she
#
# S-502: maintenant ca s ameliore !
# T-502: now it s getting better !
# H-502: she
#
# S-503: ce prix est raisonnable .
# T-503: this price is reasonable .
# H-503: i
#
# S-504: les chats ont deux oreilles .
# T-504: cats have two ears .
# H-504: we
#
# S-505: elles ont echoue .
# T-505: they have failed .
# H-505: we
#
# S-506: elle a abandonne ses enfants .
# T-506: she left her children .
# H-506: her
#
# S-507: disons le comme ca !
# T-507: let s put it like that !
# H-507: i
#
# S-508: je suis ton amie .
# T-508: i m your friend .
# H-508: he
#
# S-509: tu es capable de n importe quoi .
# T-509: you are capable of anything .
# H-509: they
#
# S-510: la moitie d entre eux sont etudiants .
# T-510: half of them are students .
# H-510: we
#
# S-511: j ai ete plutot occupee .
# T-511: i ve been kind of busy .
# H-511: if
#
# S-512: je n en ai aucune preuve .
# T-512: i have no proof of that .
# H-512: you
#
# S-513: votre temps est ecoule .
# T-513: you ve run out of time .
# H-513: he
#
# S-514: vous ne pouvez pas utiliser le sien .
# T-514: you cannot use his .
# H-514: we
#
# S-515: j etais juste curieux .
# T-515: i was just curious .
# H-515: we
#
# S-516: je comprends ton souci .
# T-516: i understand your concern .
# H-516: m
#
# S-517: vous me cachez quelque chose .
# T-517: you re hiding something from me .
# H-517: re
#
# S-518: prenez une decision !
# T-518: make a decision .
# H-518: we
#
# S-519: quel plaisir !
# T-519: what a pleasure !
# H-519: they
#
# S-520: tu es etourdie .
# T-520: you re forgetful .
# H-520: they
#
# S-521: vous etes pardonne .
# T-521: you re forgiven .
# H-521: we
#
# S-522: je suis pensionnee .
# T-522: i m retired .
# H-522: you
#
# S-523: je suis mecontente .
# T-523: i m unhappy .
# H-523: you
#
# S-524: il me le faut .
# T-524: i need it .
# H-524: you
#
# S-525: il est encore en colere .
# T-525: he s still mad .
# H-525: i
#
# S-526: elle aime danser avec ses amies .
# T-526: she likes to go to dance with her friends .
# H-526: he
#
# S-527: il a vote en faveur de la proposition .
# T-527: he voted for the proposal .
# H-527: i
#
# S-528: cette histoire me dit quelque chose .
# T-528: this story tells me something .
# H-528: you
#
# S-529: il regarde tres rarement la tele .
# T-529: he scarcely ever watches tv .
# H-529: she
#
# S-530: quel est son but ?
# T-530: what is he aiming at ?
# H-530: i
#
# S-531: il est parti en vacances .
# T-531: he is away on holiday .
# H-531: they
#
# S-532: c etait la semaine derniere .
# T-532: it was last week .
# H-532: you
#
# S-533: elles sont armees .
# T-533: they re armed .
# H-533: re
#
# S-534: ils veulent la paix .
# T-534: they want peace .
# H-534: we
#
# S-535: ils sont morts .
# T-535: they re dead .
# H-535: i
#
# S-536: elle l a battu .
# T-536: she defeated him .
# H-536: he
#
# S-537: elle est tres bonne en ski .
# T-537: she is great at skiing .
# H-537: i
#
# S-538: elle le dit avec un sourire .
# T-538: she said with a smile .
# H-538: i
#
# S-539: elle etait la seule survivante .
# T-539: she was the only survivor .
# H-539: he
#
# S-540: c est super .
# T-540: that s cool .
# H-540: i
#
# S-541: c est cool .
# T-541: that s cool .
# H-541: i
#
# S-542: qui est cette femme la ?
# T-542: who is that lady ?
# H-542: he
#
# S-543: nous nous sommes rencontres auparavant .
# T-543: we met before .
# H-543: re
#
# S-544: nous avons ete tres prudents .
# T-544: we were very careful .
# H-544: re
#
# S-545: nous sommes a mi chemin de chez nous .
# T-545: we re halfway home .
# H-545: he
#
# S-546: si tu as besoin d aide demande !
# T-546: if you need help just ask .
# H-546: he
#
# S-547: j ai choisi de ne pas partir .
# T-547: i chose not to leave .
# H-547: you
#
# S-548: non vous n etes pas excusee !
# T-548: no you re not excused !
# H-548: we
#
# S-549: essaie de ne pas me decevoir !
# T-549: try not to disappoint me .
# H-549: we
#
# S-550: peut etre n est ce pas possible .
# T-550: maybe it s not possible .
# H-550: he
#
# S-551: il y a plusieurs sorties .
# T-551: there are several exits .
# H-551: we
#
# S-552: je n y suis pas interessee .
# T-552: i m not interested in that .
# H-552: they
#
# S-553: vous n etes pas fatigue si ?
# T-553: you re not tired are you ?
# H-553: re
#
# S-554: je ne vais pas mentir .
# T-554: i m not going to lie .
# H-554: you
#
# S-555: nous n y sommes pas prets .
# T-555: we re not ready for this .
# H-555: they
#
# S-556: je ne suis pas occupee du tout .
# T-556: i m not at all busy .
# H-556: he
#
# S-557: nous demissionnons tous .
# T-557: we all quit .
# H-557: you
#
# S-558: ils ont tous regarde .
# T-558: they all watched .
# H-558: he
#
# S-559: toutes sont bienvenues .
# T-559: all are welcomed .
# H-559: i
#
# S-560: vous etes toutes malades .
# T-560: you re all insane .
# H-560: i
#
# S-561: les hommes sont tous les memes .
# T-561: men are all the same .
# H-561: he
#
# S-562: toutes mes amies disent ca .
# T-562: all my friends say that .
# H-562: i
#
# S-563: c etait de sa faute .
# T-563: it was her fault .
# H-563: i
#
# S-564: tu ne peux pas prendre ceux la !
# T-564: you can t take those !
# H-564: we
#
# S-565: tu ne peux pas prendre celles la !
# T-565: you can t take those !
# H-565: we
#
# S-566: pourriez vous nous laisser seules ?
# T-566: could you leave us alone ?
# H-566: aren
#
# S-567: sois gentil avec elle !
# T-567: be nice to her .
# H-567: he
#
# S-568: les cours commencent lundi .
# T-568: classes start on monday .
# H-568: you
#
# S-569: aujourd hui on est lundi .
# T-569: today it s monday .
# H-569: you
#
# S-570: elle dort sur le ventre .
# T-570: she sleeps on her stomach .
# H-570: we
#
# S-571: sa maison est la a droite .
# T-571: his house is there on the right .
# H-571: s
#
# S-572: vous etes tres grand .
# T-572: you re very tall .
# H-572: they
#
# S-573: ce sac a main est a moi .
# T-573: this handbag is mine .
# H-573: they
#
# S-574: tom habite la porte a cote .
# T-574: tom lives next door to us .
# H-574: he
#
# S-575: je me repose sur votre promesse .
# T-575: i rest on your promise .
# H-575: they
#
# S-576: je suis preparee .
# T-576: i m prepared .
# H-576: m
#
# S-577: il leur faut etre laves .
# T-577: they need washing .
# H-577: she
#
# S-578: on peut compter sur moi .
# T-578: i m dependable .
# H-578: you
#
# S-579: j etais coince .
# T-579: i was stuck .
# H-579: we
#
# S-580: je ne suis pas au travail aujourd hui .
# T-580: i m not at work today .
# H-580: he
#
# S-581: il est ne a rome .
# T-581: he was born in rome .
# H-581: i
#
# S-582: tom s est teint les cheveux en bleu .
# T-582: tom dyed his hair blue .
# H-582: they
#
# S-583: vous etes chinois ?
# T-583: are you chinese ?
# H-583: i
#
# S-584: je vois un petit navire .
# T-584: i see a small ship .
# H-584: he
#
# S-585: je n ai pas eu beaucoup de temps .
# T-585: i didn t have much time .
# H-585: you
#
# S-586: c est tellement dingue .
# T-586: this is so crazy .
# H-586: i
#
# S-587: elle est plus belle que tu le penses .
# T-587: she is more beautiful than you think .
# H-587: we
#
# S-588: j essaie quelque chose de nouveau .
# T-588: i m trying something new .
# H-588: we
#
# S-589: penses tu vraiment que tom peut nous entendre ?
# ...
# H-791: she
#
# S-792: c est leur probleme .
# T-792: the problem is theirs .
# H-792: they
#
# S-793: elle a accepte mon idee .
# T-793: she agreed with my idea .
# H-793: i
#
# S-794: je ne veux pas que tu sois blessee .
# T-794: i don t want you to be hurt .
# H-794: that
#
# S-795: je ne peux pas manger tout ca .
# T-795: i can t eat all of this .
# H-795: we
#
# S-796: je suis venu ici pour vous rencontrer .
# T-796: i came here to meet you .
# H-796: she
#
# S-797: je pense connaitre la reponse .
# T-797: i think i know the answer .
# H-797: she
#
# S-798: tu ne sais plus ce que tu dis .
# T-798: you don t know what you re saying right now .
# H-798: we
#
# S-799: je vous y verrai dans une heure .
# T-799: i ll meet you there in an hour .
# H-799: he
#
# S-800: je te laisse imaginer .
# T-800: i leave it to your imagination .
# H-800: he
#
# S-801: je rends souvent visite a mes proches .
# T-801: i often visit my relatives .
# H-801: they
#
# S-802: ne voulez vous pas savoir pourquoi ?
# T-802: don t you want to know why ?
# H-802: he
#
# S-803: pour toi ?
# T-803: for you ?
# H-803: he
#
# S-804: le mariage homosexuel est legal ici .
# T-804: gay marriage is legal here .
# H-804: they
#
# S-805: tu devrais sortir et t amuser .
# T-805: you should go out and have some fun .
# H-805: he
#
# S-806: je dois une excuse a beaucoup de gens .
# T-806: i owe a lot of people an apology .
# H-806: she
#
# S-807: nous avons une autre decision a prendre .
# T-807: we have another decision to make .
# H-807: you
#
# S-808: vous devez me faire confiance .
# T-808: you ve got to trust me .
# H-808: re
#
# S-809: votre ami a une mauvaise influence sur vous .
# T-809: your friend has a bad influence on you .
# H-809: he
#
# S-810: c est la honte .
# T-810: it s a shame .
# H-810: i
#
# S-811: j essaye de ne pas etre vu .
# T-811: i m trying not to be seen .
# H-811: m
#
# S-812: nous allons faire des tests .
# T-812: we re going to run some tests .
# H-812: they
#
# S-813: c est pour ca que je suis partie .
# T-813: that s why i left .
# H-813: you
#
# S-814: c est pour ca que tom a demissionne .
# T-814: that s why tom quit .
# H-814: i
#
# S-815: tu n auras pas de probleme .
# T-815: you ll have no problem .
# H-815: we
#
# S-816: ce n est plus possible .
# T-816: that s no longer possible .
# H-816: we
#
# S-817: tu n as pas l air tres fatigue .
# T-817: you don t seem to be very tired .
# H-817: he
#
# S-818: je suis venu vous aider .
# T-818: i ve come to help you .
# H-818: we
#
# S-819: j espere que marie m aidera .
# T-819: i hope mary will help me .
# H-819: we
#
# S-820: il est difficile de repondre a cette question .
# T-820: this question is difficult to answer .
# H-820: she
#
# S-821: je ne l entends pas .
# T-821: i can t hear him .
# H-821: we
#
# S-822: elles sont a la maison .
# T-822: they re at home .
# H-822: re
#
# S-823: il ne fait rien sauf pleurer .
# T-823: he does nothing but cry .
# H-823: i
#
# S-824: il me faut rester avec le groupe .
# T-824: i have to stay with the group .
# H-824: you
#
# S-825: ne mens pas a tom .
# T-825: don t lie to tom .
# H-825: he
#
# S-826: elle sera jalouse .
# T-826: she will be jealous .
# H-826: i
#
# S-827: le soleil est tres loin de la terre .
# T-827: the sun is so distant from the earth .
# H-827: we
#
# S-828: je suis mariee a un avocat .
# T-828: i m married to a lawyer .
# H-828: m
#
# S-829: pourquoi qu elle s est fachee ?
# T-829: why was it that she got angry ?
# H-829: she
#
# S-830: ne soyez pas decu .
# T-830: don t be disappointed .
# H-830: they
#
# S-831: je suis tres heureux de vous revoir .
# T-831: i m very happy to see you again .
# H-831: see
#
# S-832: que penses tu de cette phrase ?
# T-832: what do you think of this sentence ?
# H-832: she
#
# S-833: je prevois de faire ca demain .
# T-833: i m planning to do that tomorrow .
# H-833: you
#
# S-834: ou est ma biere ?
# T-834: where is my beer ?
# H-834: you
#
# S-835: ou a t elle trouve ca ?
# T-835: where did she find this ?
# H-835: she
#
# S-836: je voyage beaucoup .
# T-836: i travel around a lot .
# H-836: he
#
# S-837: je suis content que nous soyons ensemble .
# T-837: i m glad we re together .
# H-837: you
#
# S-838: je deviens plus jolie et plus lumineuse .
# T-838: i m becoming prettier and brighter .
# H-838: they
#
# S-839: je sais que le voyage a ete long .
# T-839: i know that it s been a long trip .
# H-839: she
#
# S-840: vous etes trop grand .
# T-840: you re too tall .
# H-840: they
#
# S-841: avez vous laisse un message ?
# T-841: did you leave a message ?
# H-841: we
#
# S-842: j espere vous revoir un jour .
# T-842: i hope to see you again someday .
# H-842: we
#
# S-843: ou dois je t attendre ?
# T-843: where shall i wait for you ?
# H-843: you
#
# S-844: tu es vraiment penible .
# T-844: you re a real pain .
# H-844: re
#
# S-845: attendez moi dans mon bureau .
# T-845: wait for me in my office .
# H-845: she
#
# S-846: je n ai pas envie d aller nager .
# T-846: i don t want to go swimming .
# H-846: you
#
# S-847: vous serez parfait pour ca .
# T-847: you ll be perfect for this .
# H-847: we
#
# S-848: vous serez parfaite pour ca .
# T-848: you ll be perfect for this .
# H-848: that
#
# S-849: je laisse ca a votre imagination .
# T-849: i ll leave this to your imagination .
# H-849: m
#
# S-850: je suis venue a votre recherche .
# T-850: i came looking for you .
# H-850: m
#
# S-851: j ai ete vue .
# T-851: i ve been seen .
# H-851: m
#
# S-852: avance !
# T-852: go ahead !
# H-852: we
#
# S-853: ta mere est tres jeune .
# T-853: your mother is very young .
# H-853: they
#
# S-854: john a mon age .
# T-854: john is my age .
# H-854: he
#
# S-855: de quoi ?
# T-855: about what ?
# H-855: you
#
# S-856: la table ne prend pas beaucoup de place .
# T-856: the table doesn t take up much room .
# H-856: we
#
# S-857: vous avez une question .
# T-857: you have a question .
# H-857: we
#
# S-858: le monde est grand .
# T-858: the world is big .
# H-858: they
#
# S-859: je reve beaucoup d elle .
# T-859: i dream about her a lot .
# H-859: he
#
# S-860: quel idiot vous etes !
# T-860: what an idiot you are !
# H-860: she
#
# S-861: aidez moi a sortir .
# T-861: help me get out .
# H-861: he
#
# S-862: travaille vite mange doucement .
# T-862: work fast eat slow .
# H-862: i
#
# S-863: j aime ton chat .
# T-863: i love your cat .
# H-863: we
#
# S-864: jouons au basket apres l ecole .
# T-864: let s play basketball after school .
# H-864: we
#
# S-865: vous etes plus forts que nous .
# T-865: you re stronger than us .
# H-865: they
#
# S-866: j etudie le francais en ligne .
# T-866: i study french online .
# H-866: he
#
# S-867: je suis de rio .
# T-867: i m from rio .
# H-867: he
#
# S-868: peux tu etre un peu plus precis ?
# T-868: can you be a bit more specific ?
# H-868: he
#
# S-869: les filles sont tres occupees .
# T-869: the girls are very busy .
# H-869: we
#
# S-870: je suis l amant des langues .
# T-870: i am the language lover .
# H-870: she
#
# S-871: ce n etait pas un secret .
# T-871: it wasn t a secret .
# H-871: you
#
# S-872: il est musicien et joue de plusieurs instruments .
# T-872: he s a musician and plays several instruments .
# H-872: we
#
# S-873: les questions sont les bienvenues .
# T-873: the questions are welcome .
# H-873: they
#
# S-874: ils n ont pas soif .
# T-874: they re not thirsty .
# H-874: we
#
# S-875: elle habite ici .
# T-875: she lives here .
# H-875: he
#
# S-876: avez vous votre propre appartement ?
# T-876: do you have your own apartment ?
# H-876: you
#
# S-877: tu as l air grosse dans ce pantalon .
# T-877: you look fat in those pants .
# H-877: i
#
# S-878: je peux m asseoir ici ?
# T-878: may i sit here ?
# H-878: you
#
# S-879: travailles tu samedi aussi ?
# T-879: do you work on saturday as well ?
# H-879: you
#
# S-880: fais ce qu il te plait .
# T-880: you re welcome to do anything you like .
# H-880: we
#
# S-881: je le fais pour de l argent .
# T-881: i do it for money .
# H-881: m
#
# S-882: elle sait deja lire .
# T-882: she already knows how to read .
# H-882: i
#
# S-883: elle a peur de l araignee .
# T-883: she is afraid of the spider .
# H-883: s
#
# S-884: vite a l aide .
# T-884: hurry help .
# H-884: i
#
# S-885: saute .
# T-885: jump up .
# H-885: they
#
# S-886: deteste moi !
# T-886: hate me !
# H-886: she
#
# S-887: soyez creatifs !
# T-887: be creative !
# H-887: you
#
# S-888: est ce qu il comprend bien ca ?
# T-888: does he really understand that ?
# H-888: she
#
# S-889: est ce que c est une bonne chose ?
# T-889: is that a good thing ?
# H-889: he
#
# S-890: mon fils est malade .
# T-890: my son is sick .
# H-890: she
#
# S-891: je suis ouvert d esprit .
# T-891: i have an open mind .
# H-891: you
#
# S-892: nous sommes positifs .
# T-892: we re positive .
# H-892: i
#
# S-893: a quoi joues tu ?
# T-893: what are you playing ?
# H-893: i
#
# S-894: tu as besoin d amis .
# T-894: you need friends .
# H-894: he
#
# S-895: quel age a ton garcon ?
# T-895: how old is your boy ?
# H-895: i
#
# S-896: tue la .
# T-896: kill it .
# H-896: she
#
# S-897: tom adore le ski .
# T-897: tom loves skiing .
# H-897: they
#
# S-898: tom a l air en pleine forme .
# T-898: tom looks terrific .
# H-898: you
#
# S-899: tu nous as fait peur .
# T-899: you startled us .
# H-899: they
#
# S-900: tom est nu .
# T-900: tom is naked .
# H-900: i
#
# S-901: tom m a bien eu .
# T-901: tom fooled me .
# H-901: he
#
# S-902: ces derniers temps ont ete difficiles pour tom .
# T-902: tom has been going through a rough patch lately .
# H-902: they
#
# S-903: tom prend sa retraite .
# T-903: tom is retiring .
# H-903: i
#
# S-904: ils sont a l etage .
# T-904: they re upstairs .
# H-904: i
#
# S-905: ils font des efforts .
# T-905: they re trying .
# H-905: he
#
# S-906: tom a l air fache .
# T-906: tom looks angry .
# H-906: you
#
# S-907: tom a l air gene .
# T-907: tom looks awkward .
# H-907: he
#
# S-908: tom est abattu .
# T-908: tom is despondent .
# H-908: she
#
# S-909: tom a trop confiance en lui .
# T-909: tom is overconfident .
# H-909: she
#
# S-910: j ai perdu courage .
# T-910: i lost heart .
# H-910: you
#
# S-911: reste en arriere .
# T-911: keep back .
# H-911: we
#
# S-912: tom ne s arrete jamais .
# T-912: tom never stops .
# H-912: we
#
# S-913: tom etait assis en train de lire .
# T-913: tom sat reading .
# H-913: you
#
# S-914: marie cherche son chat .
# T-914: marie is looking for her cat .
# H-914: they
#
# S-915: tu ne passes pas noel avec tom ?
# T-915: aren t you spending christmas with tom ?
# H-915: we
#
# S-916: l homme mange des haricots .
# T-916: the man is eating beans .
# H-916: she
#
# S-917: tu es formidable .
# T-917: you are fantastic .
# H-917: they
#
# S-918: vous voulez du poisson ?
# T-918: do you want fish ?
# H-918: aren
#
# S-919: tu as tout compris ?
# T-919: did you understand everything ?
# H-919: i
#
# S-920: gare a tes doigts !
# T-920: watch your fingers .
# H-920: they
#
# S-921: je l achete .
# T-921: i ll buy it .
# H-921: he
#
# S-922: essaie .
# T-922: try it .
# H-922: we
#
# S-923: du calme .
# T-923: stay cool .
# H-923: they
#
# S-924: pauvre tom !
# T-924: poor tom !
# H-924: you
#
# S-925: je suis autiste .
# T-925: i m autistic .
# H-925: they
#
# S-926: je ne suis pas aussi riche qu avant .
# T-926: i m not as rich as i once was .
# H-926: you
#
# S-927: il joue la bas .
# T-927: he plays there .
# H-927: i
#
# S-928: je ne mange que de la viande .
# T-928: i only eat meat .
# H-928: they
#
# S-929: es tu epuise ?
# T-929: are you knackered ?
# H-929: we
#
# S-930: j ai trois chats .
# T-930: i own three cats .
# H-930: m
#
# S-931: ils menent une vie aisee .
# T-931: they are well off .
# H-931: i
#
# S-932: qui va cuisiner ?
# T-932: who ll cook ?
# H-932: he
#
# S-933: j appends la dactylographie .
# T-933: i m learning how to type .
# H-933: you
#
# S-934: attention !
# T-934: careful !
# H-934: she
#
# S-935: ecoutez .
# T-935: listen .
# H-935: you
#
# S-936: papa est au boulot .
# T-936: daddy s working .
# H-936: i
#
# S-937: savez vous comment l ecrire ?
# T-937: do you know how to write it ?
# H-937: they
#
# S-938: il pense etre un bon conducteur .
# T-938: he thinks he s a good driver .
# H-938: we
#
# S-939: je sais ce qui a mal tourne .
# T-939: i know what went wrong .
# H-939: he
#
# S-940: tom le sait mieux que quiconque .
# T-940: tom knows best .
# H-940: they
#
# S-941: j ai entendu des coups de feu .
# T-941: i heard some shots .
# H-941: he
#
# S-942: j essaie d ecrire un poeme .
# T-942: i m trying to write a poem .
# H-942: we
#
# S-943: tu as ete dupe .
# T-943: you have been duped .
# H-943: they
#
# S-944: mes parents veulent divorcer .
# T-944: my parents want to divorce .
# H-944: he
#
# S-945: tom vit il encore ?
# T-945: is tom still alive ?
# H-945: you
#
# S-946: il y en a marre .
# T-946: enough !
# H-946: i
#
# S-947: nous partirons apres le petit dejeuner .
# T-947: we re setting off after breakfast .
# H-947: i
#
# S-948: il peindra la cloture demain .
# T-948: he ll paint the fence tomorrow .
# H-948: they
#
# S-949: mes nerfs sont a vif .
# T-949: my nerves are frayed .
# H-949: she
#
# S-950: nous avons une carte .
# T-950: we have a map .
# H-950: i
#
# S-951: il a taille les cerisiers .
# T-951: he has pruned the cherry trees .
# H-951: they
#
# S-952: c est bon de te voir .
# T-952: good to see you .
# H-952: he
#
# S-953: est ce que je suis un chat ?
# T-953: am i a cat ?
# H-953: you
#
# S-954: je ne suis pas un chat .
# T-954: i m not a tomcat .
# H-954: you
#
# S-955: tu as ecrit trois livres .
# T-955: you ve written three books .
# H-955: she
#
# S-956: tom a arrete de chanter .
# T-956: tom stopped singing .
# H-956: she
#
# S-957: ne le derangez pas pendant qu il dort .
# T-957: don t disturb him while he s sleeping .
# H-957: i
#
# S-958: je ne suis pas toujours aussi indulgent .
# T-958: i m not always so lenient .
# H-958: he
#
# S-959: l homme est mort .
# T-959: the man died .
# H-959: she
#
# S-960: elle dit qu elle est en colere .
# T-960: she says she s angry .
# H-960: s
#
# S-961: nous sommes ici pour le long terme .
# T-961: we re in for the long haul .
# H-961: re
#
# S-962: je suis un chauffeur de camion .
# T-962: i m a lorry driver .
# H-962: he
#
# S-963: ils ont peur d elles .
# T-963: they re afraid of them .
# H-963: re
#
# S-964: j ai oublie leurs noms .
# T-964: i forgot their names .
# H-964: he
#
# S-965: ou etaient tes enfants ?
# T-965: where were your children ?
# H-965: he
#
# S-966: elle n est pratiquement jamais chez elle .
# T-966: she s hardly ever home .
# H-966: he
#
# S-967: essayons ca .
# T-967: let s give it a whirl .
# H-967: you
#
# S-968: les vis sont plus solides que les clous .
# T-968: screws are more durable than nails .
# H-968: i
#
# S-969: il ne nous faut pas le faire maintenant .
# T-969: we don t need to do that now .
# H-969: you
#
# S-970: elle appuie sur toutes les touches du telephone .
# T-970: she is pressing all the phone buttons .
# H-970: i
#
# S-971: un pied vaut trente centimetres .
# T-971: a foot is twelve inches .
# H-971: they
#
# S-972: c est un touche a tout .
# T-972: he is a jack of all trades .
# H-972: you
#
# S-973: il y a une autre facon .
# T-973: there s another way .
# H-973: she
#
# S-974: qu est ce qu elle va faire ?
# T-974: what is she going to do ?
# H-974: we
#
# S-975: tout le monde a ete fouille .
# T-975: everyone was frisked .
# H-975: i
#
# S-976: pourquoi requiers tu ma presence ici demain ?
# T-976: why do you need me here tomorrow ?
# H-976: you
#
# S-977: desole de vous avoir fait attendre .
# T-977: i m sorry to have made you wait .
# H-977: she
#
# S-978: elles veulent que vous les aidiez .
# T-978: they want you to help them .
# H-978: he
#
# S-979: tu devrais peut etre moins boire .
# T-979: maybe you should drink less .
# H-979: she
#
# S-980: qui t a appris a jouer du piano ?
# T-980: who taught you to play the piano ?
# H-980: she
#
# S-981: mon service est presque termine .
# T-981: my shift s over soon .
# H-981: we
#
# S-982: elle a attache une photo .
# T-982: she attached a photo .
# H-982: we
#
# S-983: il se comporte plutot bizarrement ces derniers temps .
# T-983: he s been behaving rather strangely lately .
# H-983: they
#
# S-984: je veux attendre le bon moment .
# T-984: i want to wait for the right moment .
# H-984: she
#
# S-985: toi ! parle !
# T-985: you ! speak !
# H-985: we
#
# S-986: tu ne ressens vraiment rien pour moi ?
# T-986: don t you have any feelings for me at all ?
# H-986: he
#
# S-987: melangez le .
# T-987: mix it .
# H-987: we
#
# S-988: melangez les .
# T-988: mix it .
# H-988: you
#
# S-989: elles font la sieste .
# T-989: they re having a sleep after lunch .
# H-989: we
#
# S-990: les deux garcons etaient fatigues .
# T-990: both of the boys were tired .
# H-990: i
#
# S-991: je n aime pas les femmes comme ca .
# T-991: i don t like women like that .
# H-991: she
#
# S-992: je n en ai rien a foutre !
# T-992: i don t give a shit !
# H-992: m
#
# S-993: vous vous ameliorez !
# T-993: you are improving !
# H-993: we
#
# S-994: ils ont appele leur fils tom .
# T-994: they named their son tom .
# H-994: he
#
# S-995: tom a seulement trente ans .
# T-995: tom is only thirty .
# H-995: they
#
# S-996: j espere te voir bientot .
# T-996: i hope i can see you soon .
# H-996: we
